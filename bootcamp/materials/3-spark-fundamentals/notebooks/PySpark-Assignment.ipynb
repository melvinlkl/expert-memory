# %%
# Initialisation and Creation of source DFs
from pyspark.sql import SparkSession
from pyspark.sql.functions import broadcast, split, lit, avg, col

spark = SparkSession.builder.appName("Assignment").getOrCreate()

spark

match_details = spark.read.option("header", "true").option("inferSchema", "true").csv("/home/iceberg/data/match_details.csv")

matches = spark.read.option("header", "true").option("inferSchema", "true").csv("/home/iceberg/data/matches.csv").withColumnRenamed('mapid', 'map_id')

maps = spark.read.option("header", "true").option("inferSchema", "true").csv("/home/iceberg/data/maps.csv").withColumnRenamed('mapid', 'map_id')

medals = spark.read.option("header", "true").csv("/home/iceberg/data/medals.csv")

medals_matches_players = spark.read.option("header", "true").option("inferSchema", "true").csv("/home/iceberg/data/medals_matches_players.csv")
# Out:
# 24/12/25 07:39:29 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
# Create bootcamp database
spark.sql("""CREATE DATABASE IF NOT EXISTS bootcamp""")
# Out:
# DataFrame[]

# %%
# Enable Broadcast Join
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", "1000000000000") 

# Broadcast Join of Map with Matches on map_id
matches_df = matches.join(broadcast(maps),"map_id", "inner")

# Broadcast Join of Medals with Medals_Matches_Players on medal_id
medals_matches_players_df = medals_matches_players.join(broadcast(medals), "medal_id", "inner")

# Disable Broadcast Join
spark.conf.set("spark.sql.autoBroadcastJoinThreshold", "-1")

# %%
# Matches
spark.sql("""DROP TABLE IF EXISTS bootcamp.matches_bucketed""")

matches_bucketedDDL = """
CREATE TABLE IF NOT EXISTS bootcamp.matches_bucketed (
    match_id STRING,
    map_id STRING,
    name STRING,
    description STRING,
    is_team_game BOOLEAN,
    playlist_id STRING,
    completion_date DATE,
    match_duration STRING
 )
 USING iceberg
 PARTITIONED BY (bucket(16, match_id));
 """

spark.sql(matches_bucketedDDL)

matches_df.select(col("match_id"), col("map_id"), col("name"), col("description"), col("is_team_game"), col("playlist_id"), col("completion_date"), col("match_duration")) \
        .write \
        .mode("append") \
        .bucketBy(16, "match_id") \
        .saveAsTable("bootcamp.matches_bucketed")

# %%
spark.sql("""SELECT * FROM bootcamp.matches_bucketed""").collect()
# Out:
# [Row(match_id='f44c9997-eb6f-4d62-bbd4-241351d84f5c', map_id='ce1dc2de-f206-11e4-a646-24be05e24f7e', name='Truth', description=None, is_team_game=True, playlist_id='0504ca3c-de41-48f3-b9c8-3aab534d69e5', completion_date=datetime.date(2016, 2, 28), match_duration=None),
#  Row(match_id='f0f2daf2-52f3-4ff9-bb2d-ff348270cde2', map_id='cbcea2c0-f206-11e4-8c4a-24be05e24f7e', name='Riptide\xa0', description='The waters of this planet have receded', is_team_game=None, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 2, 4), match_duration=None),
#  Row(match_id='8aec419e-2bfa-4fc1-923e-5a7a4e0018b3', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 1, 7), match_duration=None),
#  Row(match_id='c6f24b65-bb73-4890-8f35-ff13c7dffaaa', map_id='cebd854f-f206-11e4-b46e-24be05e24f7e', name='Coliseum', description='Forerunner Warrior-Servants tested themselves in this arena before facing the Flood.', is_team_game=None, playlist_id='c98949ae-60a8-43dc-85d7-0feb0b92e719', completion_date=datetime.date(2016, 1, 26), match_duration=None),
#  Row(match_id='a868eb4e-8b58-4e6b-9c13-6ddd436a3dc5', map_id='c7805740-f206-11e4-982c-24be05e24f7e', name='Glacier', description="Each of Halo's microclimates can be controlled with exacting precision.", is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 2, 2), match_duration=None),
#  Row(match_id='a3c79d21-291d-4018-a319-9f5c4243e93b', map_id='cdb934b0-f206-11e4-8810-24be05e24f7e', name='Empire', description='Military-industrial concerns that power the UNSC war machine are prime targets for Insurrection factions.', is_team_game=None, playlist_id='c98949ae-60a8-43dc-85d7-0feb0b92e719', completion_date=datetime.date(2016, 1, 26), match_duration=None),
#  Row(match_id='341ede74-f260-450c-9be5-57dc7ad3027f', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=None, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 1, 26), match_duration=None),
#  Row(match_id='df9f097f-a074-4ece-9416-82547735dfb0', map_id='c96ff240-f206-11e4-b581-24be05e24f7e', name='Battle of Noctus', description='The Andesian government vowed to root the Insurrection from Noctus', is_team_game=True, playlist_id='b50c4dc2-6c86-4d79-aa8a-23a65da292c6', completion_date=datetime.date(2016, 2, 28), match_duration=None),
#  Row(match_id='39c14bb7-2a3c-44ca-b4ea-c2fd1873ec51', map_id='cd844200-f206-11e4-9393-24be05e24f7e', name='Eden', description='Only now - years after the Human-Covenant War - do many Andesian citizens feel secure enough to return to the metroplex centers.', is_team_game=None, playlist_id='c98949ae-60a8-43dc-85d7-0feb0b92e719', completion_date=datetime.date(2016, 1, 25), match_duration=None),
#  Row(match_id='ece43f80-f229-44cd-a9b1-6a65cb6cc087', map_id='caacb800-f206-11e4-81ab-24be05e24f7e', name='Plaza', description='Promesa’s streets were no stranger to organized violence.', is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 4, 5), match_duration=None),
#  Row(match_id='071c914f-7d7d-4d76-a028-5698a380a6c8', map_id='cd844200-f206-11e4-9393-24be05e24f7e', name='Eden', description='Only now - years after the Human-Covenant War - do many Andesian citizens feel secure enough to return to the metroplex centers.', is_team_game=True, playlist_id='bc0f8ad6-31e6-4a18-87d9-ad5a2dbc8212', completion_date=datetime.date(2015, 12, 27), match_duration=None),
#  Row(match_id='f143a826-fad7-4768-bacf-ffd75daea087', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=None, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 1, 26), match_duration=None),
#  Row(match_id='50594bb1-47e2-4d29-bd35-a10449cbfd67', map_id='ca737f8f-f206-11e4-a7e2-24be05e24f7e', name='Overgrowth', description='Nature has reclaimed this tomb of millions.', is_team_game=None, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 1, 26), match_duration=None),
#  Row(match_id='321f2079-fea5-4138-b4f5-434af158cfd9', map_id='5e130537-2275-40b5-9758-94b1986934ed', name=None, description=None, is_team_game=True, playlist_id='b50c4dc2-6c86-4d79-aa8a-23a65da292c6', completion_date=datetime.date(2016, 4, 10), match_duration=None),
#  Row(match_id='8f421c10-031e-46a7-b9b0-19edaab92198', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 12, 23), match_duration=None),
#  Row(match_id='aa9a0fd5-4f2c-483e-907f-e09b1c2a4b67', map_id='caacb800-f206-11e4-81ab-24be05e24f7e', name='Plaza', description='Promesa’s streets were no stranger to organized violence.', is_team_game=None, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 1, 24), match_duration=None),
#  Row(match_id='fb44f196-eab4-453d-b850-4eb2c7272535', map_id='cc040aa1-f206-11e4-a3e0-24be05e24f7e', name='Fathom', description='The UNSC explores Beta Gabriel’s vast oceans in hopes of recovering wreckage hidden in the crushing depths.', is_team_game=None, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 1, 24), match_duration=None),
#  Row(match_id='8c878eac-908e-49e8-8c09-f702bbb3ade3', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=None, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 1, 23), match_duration=None),
#  Row(match_id='34d838e6-2411-4d76-a041-959b0ebd9753', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=None, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 1, 22), match_duration=None),
#  Row(match_id='b76c333b-8391-44ff-b78a-13e6a26e9cbe', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 2, 8), match_duration=None),
#  Row(match_id='4a2013a0-9071-4563-9f06-66de137142ee', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 4, 3), match_duration=None),
#  Row(match_id='7511f978-cf03-4503-b311-9fb356db26c3', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=None, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 1, 15), match_duration=None),
#  Row(match_id='25b4b6a5-6fc2-45a6-931a-962c6a58ccfe', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=None, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 1, 15), match_duration=None),
#  Row(match_id='4f9ce4f6-7706-4962-97ef-a8a93776e956', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 12, 27), match_duration=None),
#  Row(match_id='b7bbafe8-c708-4d66-906f-f658fb9ee2be', map_id='cdee4e70-f206-11e4-87a2-24be05e24f7e', name='Regret', description=None, is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 4, 5), match_duration=None),
#  Row(match_id='e3a21bdf-08ec-46b9-9a88-8ac62d963908', map_id='cdb934b0-f206-11e4-8810-24be05e24f7e', name='Empire', description='Military-industrial concerns that power the UNSC war machine are prime targets for Insurrection factions.', is_team_game=None, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 1, 6), match_duration=None),
#  Row(match_id='d855493d-a0c7-4a69-ba46-bd3d12bd7f02', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=None, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 1, 3), match_duration=None),
#  Row(match_id='8b3de310-6c5d-4589-9c76-bb750f1e923e', map_id='c96ff240-f206-11e4-b581-24be05e24f7e', name='Battle of Noctus', description='The Andesian government vowed to root the Insurrection from Noctus', is_team_game=True, playlist_id='b50c4dc2-6c86-4d79-aa8a-23a65da292c6', completion_date=datetime.date(2016, 2, 2), match_duration=None),
#  Row(match_id='999dc84d-59ed-4ed8-9365-8428d0bedd74', map_id='cd844200-f206-11e4-9393-24be05e24f7e', name='Eden', description='Only now - years after the Human-Covenant War - do many Andesian citizens feel secure enough to return to the metroplex centers.', is_team_game=None, playlist_id='5728f612-3f20-4459-98bd-3478c79c4861', completion_date=datetime.date(2016, 1, 2), match_duration=None),
#  Row(match_id='6bf8a3bd-8098-426f-8aa4-d7ee81824e03', map_id='cdb934b0-f206-11e4-8810-24be05e24f7e', name='Empire', description='Military-industrial concerns that power the UNSC war machine are prime targets for Insurrection factions.', is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 3, 18), match_duration=None),
#  Row(match_id='904a9860-865e-44cb-8e63-395e9daa8473', map_id='ca737f8f-f206-11e4-a7e2-24be05e24f7e', name='Overgrowth', description='Nature has reclaimed this tomb of millions.', is_team_game=None, playlist_id='d0766624-dbd7-4536-ba39-2d890a6143a9', completion_date=datetime.date(2016, 1, 1), match_duration=None),
#  Row(match_id='dbfb1a41-aeec-420e-835c-390e849e2612', map_id='cb914b9e-f206-11e4-b447-24be05e24f7e', name='The Rig', description='Humanity’s ravenous engines of industry require salvaging vast amounts of rare metals from Meridian’s vitrified surface.', is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 4, 10), match_duration=None),
#  Row(match_id='d68b336f-0f2f-4469-924d-077b688a590a', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=None, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 12, 27), match_duration=None),
#  Row(match_id='6a29c802-baf6-40e9-83c7-e1c6533af37c', map_id='c74c9d0f-f206-11e4-8330-24be05e24f7e', name='Alpine', description='These vistas are Forerunner mementos', is_team_game=None, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2015, 12, 28), match_duration=None),
#  Row(match_id='0e3d14b7-5c7b-46db-8da3-edfef9c99414', map_id='cb914b9e-f206-11e4-b447-24be05e24f7e', name='The Rig', description='Humanity’s ravenous engines of industry require salvaging vast amounts of rare metals from Meridian’s vitrified surface.', is_team_game=None, playlist_id='d0766624-dbd7-4536-ba39-2d890a6143a9', completion_date=datetime.date(2015, 12, 27), match_duration=None),
#  Row(match_id='61669c2a-810a-4b1f-af71-493a8233844d', map_id='ca737f8f-f206-11e4-a7e2-24be05e24f7e', name='Overgrowth', description='Nature has reclaimed this tomb of millions.', is_team_game=None, playlist_id='892189e9-d712-4bdb-afa7-1ccab43fbed4', completion_date=datetime.date(2015, 12, 27), match_duration=None),
#  Row(match_id='3d8abc42-b6db-4827-9d03-0e67a27745bc', map_id='cb914b9e-f206-11e4-b447-24be05e24f7e', name='The Rig', description='Humanity’s ravenous engines of industry require salvaging vast amounts of rare metals from Meridian’s vitrified surface.', is_team_game=None, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2015, 12, 27), match_duration=None),
#  Row(match_id='3eaa4ea5-bcf0-40f5-be84-f721b4343d8a', map_id='cdee4e70-f206-11e4-87a2-24be05e24f7e', name='Regret', description=None, is_team_game=None, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2015, 12, 27), match_duration=None),
#  Row(match_id='f0c811e3-7cb0-449e-8a06-97c4c66d6662', map_id='c822b1c0-f206-11e4-9755-24be05e24f7e', name='Summit', description='The half-real spaces at the heart of Kamchatka slowly turn over the long march of eons', is_team_game=True, playlist_id='0e39ead4-383b-4452-bbd4-babb7becd82e', completion_date=datetime.date(2016, 3, 2), match_duration=None),
#  Row(match_id='77b174a3-332b-4137-8ad7-27cd20f07246', map_id='c7805740-f206-11e4-982c-24be05e24f7e', name='Glacier', description="Each of Halo's microclimates can be controlled with exacting precision.", is_team_game=True, playlist_id='355dc154-9809-4edb-8ed4-fff910c6ae9c', completion_date=datetime.date(2016, 2, 27), match_duration=None),
#  Row(match_id='863019dc-4b0a-439f-bda0-64cb7a47f041', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=None, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 12, 26), match_duration=None),
#  Row(match_id='ed95ad0f-04ea-44ca-a366-778f9b005d46', map_id='ca737f8f-f206-11e4-a7e2-24be05e24f7e', name='Overgrowth', description='Nature has reclaimed this tomb of millions.', is_team_game=True, playlist_id='892189e9-d712-4bdb-afa7-1ccab43fbed4', completion_date=datetime.date(2016, 3, 31), match_duration=None),
#  Row(match_id='f1e0cdc7-b0ab-43e6-ad00-a55ad70262ea', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=None, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 12, 24), match_duration=None),
#  Row(match_id='21793028-cf13-4c35-b70c-6ce30b3bdcb5', map_id='ca737f8f-f206-11e4-a7e2-24be05e24f7e', name='Overgrowth', description='Nature has reclaimed this tomb of millions.', is_team_game=None, playlist_id='c98949ae-60a8-43dc-85d7-0feb0b92e719', completion_date=datetime.date(2015, 12, 24), match_duration=None),
#  Row(match_id='c2f4e3d0-df51-4b54-80e0-0edba6ccf01b', map_id='c854e54f-f206-11e4-bddc-24be05e24f7e', name='March on Stormbreak', description=None, is_team_game=True, playlist_id='b50c4dc2-6c86-4d79-aa8a-23a65da292c6', completion_date=datetime.date(2016, 1, 17), match_duration=None),
#  Row(match_id='fb3e183f-7648-4420-b931-3c3421ed6265', map_id='cb914b9e-f206-11e4-b447-24be05e24f7e', name='The Rig', description='Humanity’s ravenous engines of industry require salvaging vast amounts of rare metals from Meridian’s vitrified surface.', is_team_game=None, playlist_id='d0766624-dbd7-4536-ba39-2d890a6143a9', completion_date=datetime.date(2015, 12, 23), match_duration=None),
#  Row(match_id='54469058-caa6-441d-92ac-09a9bfd786a6', map_id='ca737f8f-f206-11e4-a7e2-24be05e24f7e', name='Overgrowth', description='Nature has reclaimed this tomb of millions.', is_team_game=None, playlist_id='d0766624-dbd7-4536-ba39-2d890a6143a9', completion_date=datetime.date(2015, 12, 23), match_duration=None),
#  Row(match_id='c09cc95d-c699-4800-8629-347da005b167', map_id='cdee4e70-f206-11e4-87a2-24be05e24f7e', name='Regret', description=None, is_team_game=None, playlist_id='d0766624-dbd7-4536-ba39-2d890a6143a9', completion_date=datetime.date(2015, 12, 24), match_duration=None),
#  Row(match_id='286db54c-8c1c-436d-adc1-56e939fdff6f', map_id='caacb800-f206-11e4-81ab-24be05e24f7e', name='Plaza', description='Promesa’s streets were no stranger to organized violence.', is_team_game=None, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2015, 12, 21), match_duration=None),
#  Row(match_id='869d3b14-c021-4219-8294-4b0e6d08b13d', map_id='c7805740-f206-11e4-982c-24be05e24f7e', name='Glacier', description="Each of Halo's microclimates can be controlled with exacting precision.", is_team_game=True, playlist_id='780cc101-005c-4fca-8ce7-6f36d7156ffe', completion_date=datetime.date(2016, 2, 27), match_duration=None),
#  Row(match_id='6c58e84b-9b23-4c6c-8a49-8e1fb35097c8', map_id='c96ff240-f206-11e4-b581-24be05e24f7e', name='Battle of Noctus', description='The Andesian government vowed to root the Insurrection from Noctus', is_team_game=True, playlist_id='b50c4dc2-6c86-4d79-aa8a-23a65da292c6', completion_date=datetime.date(2015, 12, 27), match_duration=None),
#  Row(match_id='38eabc18-900a-4517-a7f5-40fb6fae5bc4', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 1, 17), match_duration=None),
#  Row(match_id='a16187de-13fa-409e-98ad-ef5576dfe5f9', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=None, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 12, 11), match_duration=None),
#  Row(match_id='a4124a34-12fd-4ef6-8625-42b067d80639', map_id='cdee4e70-f206-11e4-87a2-24be05e24f7e', name='Regret', description=None, is_team_game=None, playlist_id='f27a65eb-2d11-4965-aa9c-daa088fa5c9c', completion_date=datetime.date(2015, 12, 12), match_duration=None),
#  Row(match_id='9c08fd38-3f16-4843-b351-ff6e8a4d6261', map_id='cdee4e70-f206-11e4-87a2-24be05e24f7e', name='Regret', description=None, is_team_game=None, playlist_id='7b7e892c-d9b7-4b03-bef8-c6a071df28ef', completion_date=datetime.date(2015, 12, 13), match_duration=None),
#  Row(match_id='04fa07b0-d3eb-4487-8687-4862a0d6f7f8', map_id='cdb934b0-f206-11e4-8810-24be05e24f7e', name='Empire', description='Military-industrial concerns that power the UNSC war machine are prime targets for Insurrection factions.', is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 3, 2), match_duration=None),
#  Row(match_id='b5f5a2c3-0c18-4ef0-b263-fef4ce42ef69', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=None, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 12, 10), match_duration=None),
#  Row(match_id='6258fe3f-2665-4407-ba68-bf638ffae4b8', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=None, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 12, 10), match_duration=None),
#  Row(match_id='667f6edf-6248-4f33-aac0-203b5656872b', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 5, 18), match_duration=None),
#  Row(match_id='a0241a15-924f-4aa0-b82b-8e37dedfa3a4', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=None, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 12, 8), match_duration=None),
#  Row(match_id='0c5e307e-4c4a-4723-ade5-aebf03dbdc12', map_id='ca737f8f-f206-11e4-a7e2-24be05e24f7e', name='Overgrowth', description='Nature has reclaimed this tomb of millions.', is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 4, 5), match_duration=None),
#  Row(match_id='08f8f2e7-3e5d-47fe-94d0-af90c6af37d6', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 2, 6), match_duration=None),
#  Row(match_id='fdef673e-7ca9-4c3e-ada9-66bfc67ad40a', map_id='cc040aa1-f206-11e4-a3e0-24be05e24f7e', name='Fathom', description='The UNSC explores Beta Gabriel’s vast oceans in hopes of recovering wreckage hidden in the crushing depths.', is_team_game=None, playlist_id='7385b4a1-86bf-4aec-b9c2-411a6aa48633', completion_date=datetime.date(2015, 12, 6), match_duration=None),
#  Row(match_id='1d8b246f-3b2e-42fb-88a1-1ba770d87783', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=None, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 12, 6), match_duration=None),
#  Row(match_id='fbfa213f-7e82-402d-9c1c-2b1faf1f1379', map_id='cb914b9e-f206-11e4-b447-24be05e24f7e', name='The Rig', description='Humanity’s ravenous engines of industry require salvaging vast amounts of rare metals from Meridian’s vitrified surface.', is_team_game=None, playlist_id='7385b4a1-86bf-4aec-b9c2-411a6aa48633', completion_date=datetime.date(2015, 12, 5), match_duration=None),
#  Row(match_id='bd2f6cab-c3e6-47ad-ab8a-1cf9236eae35', map_id='cb251c51-f206-11e4-8541-24be05e24f7e', name='Raid on Apex 7', description='This unbroken ring is a symbol of the discovery that shook the galaxy and changed the course of both human and Covenant destiny.', is_team_game=True, playlist_id='b50c4dc2-6c86-4d79-aa8a-23a65da292c6', completion_date=datetime.date(2015, 12, 27), match_duration=None),
#  Row(match_id='e9cf2f52-76cd-42f7-8348-9b21cdc74af3', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 5, 17), match_duration=None),
#  Row(match_id='a159a01f-75a5-4c1a-8c77-f20ff24ed2c5', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 2, 9), match_duration=None),
#  Row(match_id='1e387c1f-8ab6-4bc7-b565-6b971ddd1a8c', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=None, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 11, 22), match_duration=None),
#  Row(match_id='aeb093b4-1c09-41b4-9495-70872d622d0c', map_id='c74c9d0f-f206-11e4-8330-24be05e24f7e', name='Alpine', description='These vistas are Forerunner mementos', is_team_game=None, playlist_id='f27a65eb-2d11-4965-aa9c-daa088fa5c9c', completion_date=datetime.date(2015, 11, 11), match_duration=None),
#  Row(match_id='1af4a0f5-1c10-4240-be96-c8d81f69dd06', map_id='caacb800-f206-11e4-81ab-24be05e24f7e', name='Plaza', description='Promesa’s streets were no stranger to organized violence.', is_team_game=True, playlist_id='892189e9-d712-4bdb-afa7-1ccab43fbed4', completion_date=datetime.date(2016, 5, 9), match_duration=None),
#  Row(match_id='3f05eda6-dacd-4ac7-afb0-7e1a9eb3725b', map_id='caacb800-f206-11e4-81ab-24be05e24f7e', name='Plaza', description='Promesa’s streets were no stranger to organized violence.', is_team_game=None, playlist_id='f27a65eb-2d11-4965-aa9c-daa088fa5c9c', completion_date=datetime.date(2015, 11, 22), match_duration=None),
#  Row(match_id='4cf7ecfa-402c-413d-b190-1b5235566c73', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=None, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 11, 11), match_duration=None),
#  Row(match_id='ac0dbceb-e9c1-419c-8a06-656fc30029f4', map_id='c822b1c0-f206-11e4-9755-24be05e24f7e', name='Summit', description='The half-real spaces at the heart of Kamchatka slowly turn over the long march of eons', is_team_game=True, playlist_id='0e39ead4-383b-4452-bbd4-babb7becd82e', completion_date=datetime.date(2016, 3, 1), match_duration=None),
#  Row(match_id='ab4d9b34-95cf-4eb2-8d30-d8c3e46a8ff5', map_id='ce1dc2de-f206-11e4-a646-24be05e24f7e', name='Truth', description=None, is_team_game=None, playlist_id='c98949ae-60a8-43dc-85d7-0feb0b92e719', completion_date=datetime.date(2015, 11, 9), match_duration=None),
#  Row(match_id='b3eceef1-f002-4329-8864-9eba82068871', map_id='cd844200-f206-11e4-9393-24be05e24f7e', name='Eden', description='Only now - years after the Human-Covenant War - do many Andesian citizens feel secure enough to return to the metroplex centers.', is_team_game=None, playlist_id='f27a65eb-2d11-4965-aa9c-daa088fa5c9c', completion_date=datetime.date(2015, 11, 5), match_duration=None),
#  Row(match_id='7d9f3d4f-d8ce-4588-96aa-e722727db192', map_id='cb914b9e-f206-11e4-b447-24be05e24f7e', name='The Rig', description='Humanity’s ravenous engines of industry require salvaging vast amounts of rare metals from Meridian’s vitrified surface.', is_team_game=None, playlist_id='892189e9-d712-4bdb-afa7-1ccab43fbed4', completion_date=datetime.date(2015, 11, 1), match_duration=None),
#  Row(match_id='4017b461-15af-4d0d-bbff-ca38c0e90a90', map_id='cb914b9e-f206-11e4-b447-24be05e24f7e', name='The Rig', description='Humanity’s ravenous engines of industry require salvaging vast amounts of rare metals from Meridian’s vitrified surface.', is_team_game=True, playlist_id='4b12472e-2a06-4235-ba58-f376be6c1b39', completion_date=datetime.date(2015, 12, 13), match_duration=None),
#  Row(match_id='3ef80613-28bd-4894-a1d2-0208d396d631', map_id='cae999f0-f206-11e4-9835-24be05e24f7e', name='Array', description='Halo erased a hundred billion possibilities to destroy a single inevitability.', is_team_game=True, playlist_id='0e39ead4-383b-4452-bbd4-babb7becd82e', completion_date=datetime.date(2016, 2, 8), match_duration=None),
#  Row(match_id='843898b3-b4ff-4558-b6a4-0419845f443f', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 12, 15), match_duration=None),
#  Row(match_id='cae4d483-4a55-43ea-8168-e5c502b4d895', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 2, 19), match_duration=None),
#  Row(match_id='47e142aa-33db-4fb1-8f1f-d5160ff133dd', map_id='c96ff240-f206-11e4-b581-24be05e24f7e', name='Battle of Noctus', description='The Andesian government vowed to root the Insurrection from Noctus', is_team_game=True, playlist_id='b50c4dc2-6c86-4d79-aa8a-23a65da292c6', completion_date=datetime.date(2016, 3, 4), match_duration=None),
#  Row(match_id='22d73fe6-43de-40ba-90f6-e6b0d68e8f92', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 3, 16), match_duration=None),
#  Row(match_id='9dfb731f-30d8-4e55-84a2-4fc132c87c88', map_id='c8d69870-f206-11e4-b477-24be05e24f7e', name='Escape from A.R.C.', description='Scientists flocked to this Forerunner excavation in search of new beginnings. What they unearthed will lead to their inevitable end.', is_team_game=True, playlist_id='b50c4dc2-6c86-4d79-aa8a-23a65da292c6', completion_date=datetime.date(2016, 1, 21), match_duration=None),
#  Row(match_id='70ad489e-cf79-48d3-82b6-2cec23d207b8', map_id='cae999f0-f206-11e4-9835-24be05e24f7e', name='Array', description='Halo erased a hundred billion possibilities to destroy a single inevitability.', is_team_game=True, playlist_id='0e39ead4-383b-4452-bbd4-babb7becd82e', completion_date=datetime.date(2015, 11, 4), match_duration=None),
#  Row(match_id='1780e1d1-eeac-4517-9f3a-cd59311e9104', map_id='cdee4e70-f206-11e4-87a2-24be05e24f7e', name='Regret', description=None, is_team_game=True, playlist_id='819eb188-1a1c-48b4-9af3-283d2447ff6f', completion_date=datetime.date(2015, 11, 7), match_duration=None),
#  Row(match_id='f189d06e-ce35-4c3a-b6d6-48ed4d0335dd', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 4, 28), match_duration=None),
#  Row(match_id='363034d2-77b8-4f23-b14e-83b6e79fc699', map_id='c7805740-f206-11e4-982c-24be05e24f7e', name='Glacier', description="Each of Halo's microclimates can be controlled with exacting precision.", is_team_game=True, playlist_id='355dc154-9809-4edb-8ed4-fff910c6ae9c', completion_date=datetime.date(2016, 3, 7), match_duration=None),
#  Row(match_id='aea00576-ebcb-4ce8-b986-21ad77d0cecf', map_id='caacb800-f206-11e4-81ab-24be05e24f7e', name='Plaza', description='Promesa’s streets were no stranger to organized violence.', is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 2, 15), match_duration=None),
#  Row(match_id='4a79d75f-6366-4101-897f-ac2a3618d3bd', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 1, 8), match_duration=None),
#  Row(match_id='1a6678fb-3c98-4133-a82a-3bd0368247ee', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 12, 15), match_duration=None),
#  Row(match_id='5db57782-f10a-4923-85b2-a92120d1c482', map_id='cae999f0-f206-11e4-9835-24be05e24f7e', name='Array', description='Halo erased a hundred billion possibilities to destroy a single inevitability.', is_team_game=True, playlist_id='0e39ead4-383b-4452-bbd4-babb7becd82e', completion_date=datetime.date(2016, 2, 9), match_duration=None),
#  Row(match_id='83ad81e6-1cf7-4569-9f09-39946fa4c144', map_id='cbcea2c0-f206-11e4-8c4a-24be05e24f7e', name='Riptide\xa0', description='The waters of this planet have receded', is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 2, 20), match_duration=None),
#  Row(match_id='efb39c4e-c0fb-4c30-93d6-3ad1e8a4edcc', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 2, 20), match_duration=None),
#  Row(match_id='1c5afef4-2375-43cb-b4a3-5df3460896d4', map_id='cdb934b0-f206-11e4-8810-24be05e24f7e', name='Empire', description='Military-industrial concerns that power the UNSC war machine are prime targets for Insurrection factions.', is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 2, 5), match_duration=None),
#  Row(match_id='fb946e2e-7e0d-4b33-96e5-cd761404dbd9', map_id='ca737f8f-f206-11e4-a7e2-24be05e24f7e', name='Overgrowth', description='Nature has reclaimed this tomb of millions.', is_team_game=True, playlist_id='c98949ae-60a8-43dc-85d7-0feb0b92e719', completion_date=datetime.date(2016, 2, 20), match_duration=None),
#  Row(match_id='91eb1456-0ac4-4e84-a262-ee088db42f52', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 5, 12), match_duration=None),
#  Row(match_id='857666a6-b728-428d-8513-e7fe196dbc54', map_id='cb251c51-f206-11e4-8541-24be05e24f7e', name='Raid on Apex 7', description='This unbroken ring is a symbol of the discovery that shook the galaxy and changed the course of both human and Covenant destiny.', is_team_game=True, playlist_id='b50c4dc2-6c86-4d79-aa8a-23a65da292c6', completion_date=datetime.date(2016, 2, 28), match_duration=None),
#  Row(match_id='c2fe217b-fb58-4cfa-a5de-ca04c4cfcebd', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 2, 8), match_duration=None),
#  Row(match_id='c123d68a-af21-4fe0-b850-bc14a2a0b881', map_id='ca737f8f-f206-11e4-a7e2-24be05e24f7e', name='Overgrowth', description='Nature has reclaimed this tomb of millions.', is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 2, 19), match_duration=None),
#  Row(match_id='6badbb89-d5e0-4b82-bb7a-4c57fcc5f645', map_id='cebd854f-f206-11e4-b46e-24be05e24f7e', name='Coliseum', description='Forerunner Warrior-Servants tested themselves in this arena before facing the Flood.', is_team_game=True, playlist_id='c98949ae-60a8-43dc-85d7-0feb0b92e719', completion_date=datetime.date(2016, 2, 15), match_duration=None),
#  Row(match_id='1db34c3a-ba14-42c9-9f85-220b48fea7ab', map_id='c7805740-f206-11e4-982c-24be05e24f7e', name='Glacier', description="Each of Halo's microclimates can be controlled with exacting precision.", is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 2, 15), match_duration=None),
#  Row(match_id='b49ef028-6a85-4c4c-9872-ce0bca0a7024', map_id='cd844200-f206-11e4-9393-24be05e24f7e', name='Eden', description='Only now - years after the Human-Covenant War - do many Andesian citizens feel secure enough to return to the metroplex centers.', is_team_game=True, playlist_id='c98949ae-60a8-43dc-85d7-0feb0b92e719', completion_date=datetime.date(2016, 2, 1), match_duration=None),
#  Row(match_id='c99873db-9a08-4993-bb51-a774fd67b750', map_id='cdee4e70-f206-11e4-87a2-24be05e24f7e', name='Regret', description=None, is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 4, 17), match_duration=None),
#  Row(match_id='0727c539-a256-4dac-b205-e357b593be42', map_id='cdb934b0-f206-11e4-8810-24be05e24f7e', name='Empire', description='Military-industrial concerns that power the UNSC war machine are prime targets for Insurrection factions.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 2, 3), match_duration=None),
#  Row(match_id='846784c1-5674-4b6f-adff-75566b152040', map_id='cb914b9e-f206-11e4-b447-24be05e24f7e', name='The Rig', description='Humanity’s ravenous engines of industry require salvaging vast amounts of rare metals from Meridian’s vitrified surface.', is_team_game=True, playlist_id='5728f612-3f20-4459-98bd-3478c79c4861', completion_date=datetime.date(2015, 11, 15), match_duration=None),
#  Row(match_id='31d94dda-b460-4814-85c0-ea8ce4f0242e', map_id='cdb934b0-f206-11e4-8810-24be05e24f7e', name='Empire', description='Military-industrial concerns that power the UNSC war machine are prime targets for Insurrection factions.', is_team_game=True, playlist_id='c98949ae-60a8-43dc-85d7-0feb0b92e719', completion_date=datetime.date(2016, 2, 6), match_duration=None),
#  Row(match_id='b6c61b13-009f-4eb0-bf9c-dd4bdc1fc9b8', map_id='c854e54f-f206-11e4-bddc-24be05e24f7e', name='March on Stormbreak', description=None, is_team_game=True, playlist_id='b50c4dc2-6c86-4d79-aa8a-23a65da292c6', completion_date=datetime.date(2016, 2, 28), match_duration=None),
#  Row(match_id='1e881269-3e51-4571-b27d-38fad49df080', map_id='c74c9d0f-f206-11e4-8330-24be05e24f7e', name='Alpine', description='These vistas are Forerunner mementos', is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 3, 18), match_duration=None),
#  Row(match_id='ac3f8a68-f32e-4f19-bbce-565805a25939', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 2, 12), match_duration=None),
#  Row(match_id='a0757867-586a-4b06-b9d7-5335bff6c4a6', map_id='caacb800-f206-11e4-81ab-24be05e24f7e', name='Plaza', description='Promesa’s streets were no stranger to organized violence.', is_team_game=False, playlist_id='d0766624-dbd7-4536-ba39-2d890a6143a9', completion_date=datetime.date(2016, 2, 20), match_duration=None),
#  Row(match_id='2c047996-d29b-4dae-9bae-cd849809004f', map_id='cdee4e70-f206-11e4-87a2-24be05e24f7e', name='Regret', description=None, is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 5, 12), match_duration=None),
#  Row(match_id='b0d38bfe-2674-4e1d-8daa-051b51b03944', map_id='cebd854f-f206-11e4-b46e-24be05e24f7e', name='Coliseum', description='Forerunner Warrior-Servants tested themselves in this arena before facing the Flood.', is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 3, 19), match_duration=None),
#  Row(match_id='27060fcb-a7f1-41f4-b2f8-935705939828', map_id='c7b7baf0-f206-11e4-ae9a-24be05e24f7e', name='Parallax', description='The Orion Arm of the galaxy teems with danger and opportunity.', is_team_game=True, playlist_id='780cc101-005c-4fca-8ce7-6f36d7156ffe', completion_date=datetime.date(2016, 2, 21), match_duration=None),
#  Row(match_id='ca56f971-7304-4beb-af89-8811770e67cd', map_id='cdee4e70-f206-11e4-87a2-24be05e24f7e', name='Regret', description=None, is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 2, 28), match_duration=None),
#  Row(match_id='a5c5a971-58fc-4acf-bb43-ee32f4b23dde', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 1, 19), match_duration=None),
#  Row(match_id='944fec1e-1d12-44d4-8a0b-d2f7bd6d8e8c', map_id='caacb800-f206-11e4-81ab-24be05e24f7e', name='Plaza', description='Promesa’s streets were no stranger to organized violence.', is_team_game=False, playlist_id='d0766624-dbd7-4536-ba39-2d890a6143a9', completion_date=datetime.date(2016, 2, 28), match_duration=None),
#  Row(match_id='89d1dfa7-6dce-4953-98eb-1884ed2f1ae0', map_id='c74c9d0f-f206-11e4-8330-24be05e24f7e', name='Alpine', description='These vistas are Forerunner mementos', is_team_game=True, playlist_id='780cc101-005c-4fca-8ce7-6f36d7156ffe', completion_date=datetime.date(2016, 2, 28), match_duration=None),
#  Row(match_id='88e93437-31ae-49e9-b98a-948620718392', map_id='cebd854f-f206-11e4-b46e-24be05e24f7e', name='Coliseum', description='Forerunner Warrior-Servants tested themselves in this arena before facing the Flood.', is_team_game=True, playlist_id='c98949ae-60a8-43dc-85d7-0feb0b92e719', completion_date=datetime.date(2015, 11, 4), match_duration=None),
#  Row(match_id='8c54c443-4114-4c2d-94e4-1dd8fee9d909', map_id='c74c9d0f-f206-11e4-8330-24be05e24f7e', name='Alpine', description='These vistas are Forerunner mementos', is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 2, 3), match_duration=None),
#  Row(match_id='c91bfed3-75ca-4ae0-b605-8b5b347595eb', map_id='c7805740-f206-11e4-982c-24be05e24f7e', name='Glacier', description="Each of Halo's microclimates can be controlled with exacting precision.", is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 2, 27), match_duration=None),
#  Row(match_id='61224123-e5b1-4f09-8d95-835c4b687e2b', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 11, 5), match_duration=None),
#  Row(match_id='37e39270-4b58-4003-85af-b1bcf11001c2', map_id='cd844200-f206-11e4-9393-24be05e24f7e', name='Eden', description='Only now - years after the Human-Covenant War - do many Andesian citizens feel secure enough to return to the metroplex centers.', is_team_game=None, playlist_id='c98949ae-60a8-43dc-85d7-0feb0b92e719', completion_date=datetime.date(2015, 11, 15), match_duration=None),
#  Row(match_id='122a16a7-8674-4765-8d0d-93c379a35408', map_id='cc040aa1-f206-11e4-a3e0-24be05e24f7e', name='Fathom', description='The UNSC explores Beta Gabriel’s vast oceans in hopes of recovering wreckage hidden in the crushing depths.', is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 2, 25), match_duration=None),
#  Row(match_id='1d7dd39a-4673-47cf-9764-9c263714b7f3', map_id='cd844200-f206-11e4-9393-24be05e24f7e', name='Eden', description='Only now - years after the Human-Covenant War - do many Andesian citizens feel secure enough to return to the metroplex centers.', is_team_game=True, playlist_id='f27a65eb-2d11-4965-aa9c-daa088fa5c9c', completion_date=datetime.date(2015, 11, 7), match_duration=None),
#  Row(match_id='a3e35554-0d66-49e0-a08e-be476e50f380', map_id='c89dae21-f206-11e4-a1c2-24be05e24f7e', name='Dispatch', description=None, is_team_game=True, playlist_id='0e39ead4-383b-4452-bbd4-babb7becd82e', completion_date=datetime.date(2016, 3, 18), match_duration=None),
#  Row(match_id='aff600b4-d277-4451-8b0b-c41b02baf9c4', map_id='c74c9d0f-f206-11e4-8330-24be05e24f7e', name='Alpine', description='These vistas are Forerunner mementos', is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 4, 5), match_duration=None),
#  Row(match_id='fe1f28fe-b9c6-4a71-b095-bf9c33bd588c', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 12, 22), match_duration=None),
#  Row(match_id='5c7e75c5-7880-4313-8814-ec8b0b633bea', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 5, 1), match_duration=None),
#  Row(match_id='04d7a744-4142-4021-895c-1e6bb3f84d39', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 3, 31), match_duration=None),
#  Row(match_id='3deb53e8-5e24-4f30-888f-b48528d277a9', map_id='cb914b9e-f206-11e4-b447-24be05e24f7e', name='The Rig', description='Humanity’s ravenous engines of industry require salvaging vast amounts of rare metals from Meridian’s vitrified surface.', is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 4, 11), match_duration=None),
#  Row(match_id='4d89aa05-b6ce-4a32-bdce-ca649d8bd20a', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 5, 18), match_duration=None),
#  Row(match_id='3d97b394-d83c-4972-b736-371762365e82', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 1, 16), match_duration=None),
#  Row(match_id='6dd98242-0e2f-4447-8c03-c3f6670ad069', map_id='c7b7baf0-f206-11e4-ae9a-24be05e24f7e', name='Parallax', description='The Orion Arm of the galaxy teems with danger and opportunity.', is_team_game=True, playlist_id='780cc101-005c-4fca-8ce7-6f36d7156ffe', completion_date=datetime.date(2016, 2, 24), match_duration=None),
#  Row(match_id='c0bde7e7-4e15-476e-a624-24cf570a4507', map_id='cb914b9e-f206-11e4-b447-24be05e24f7e', name='The Rig', description='Humanity’s ravenous engines of industry require salvaging vast amounts of rare metals from Meridian’s vitrified surface.', is_team_game=True, playlist_id='f27a65eb-2d11-4965-aa9c-daa088fa5c9c', completion_date=datetime.date(2015, 11, 8), match_duration=None),
#  Row(match_id='1ff84f77-4bac-4552-b992-6d3366c2bdce', map_id='caacb800-f206-11e4-81ab-24be05e24f7e', name='Plaza', description='Promesa’s streets were no stranger to organized violence.', is_team_game=True, playlist_id='5728f612-3f20-4459-98bd-3478c79c4861', completion_date=datetime.date(2016, 1, 1), match_duration=None),
#  Row(match_id='a5b8c85c-b6c7-4ddf-b0d3-f40f4c882c06', map_id='ce1dc2de-f206-11e4-a646-24be05e24f7e', name='Truth', description=None, is_team_game=True, playlist_id='892189e9-d712-4bdb-afa7-1ccab43fbed4', completion_date=datetime.date(2016, 3, 27), match_duration=None),
# ...
#  Row(match_id='35c7ace5-16d0-4de8-9c6f-6ae239d017b3', map_id='c96ff240-f206-11e4-b581-24be05e24f7e', name='Battle of Noctus', description='The Andesian government vowed to root the Insurrection from Noctus', is_team_game=True, playlist_id='b50c4dc2-6c86-4d79-aa8a-23a65da292c6', completion_date=datetime.date(2016, 1, 22), match_duration=None),
#  Row(match_id='fd845d48-e845-4528-a23f-e38ab02ca62a', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 3, 13), match_duration=None),
#  Row(match_id='841b1bf0-9fb6-4769-88cf-a0901e658257', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 1, 15), match_duration=None),
#  Row(match_id='8f019e5d-a3c7-43c1-8368-6fa478917e19', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 11, 29), match_duration=None),
#  Row(match_id='b4b1b79c-866a-4158-8141-62c09f2fcb0b', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 3, 26), match_duration=None),
#  Row(match_id='883914cd-7fa6-48c9-9887-b8607f9e058c', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 12, 27), match_duration=None),
#  Row(match_id='8a9da3f3-5f67-4b04-8d8b-b345d1e37fd1', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 3, 13), match_duration=None),
#  Row(match_id='27a48479-0e56-4b32-8751-be89cbe918aa', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 5, 1), match_duration=None),
#  Row(match_id='5df28799-8076-4190-880b-d4aed3989222', map_id='cc74f4e1-f206-11e4-ad66-24be05e24f7e', name=None, description=None, is_team_game=True, playlist_id='bc0f8ad6-31e6-4a18-87d9-ad5a2dbc8212', completion_date=datetime.date(2016, 4, 25), match_duration=None),
#  Row(match_id='db2286fd-c2bc-4960-9068-98895d6b9f1a', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 2, 29), match_duration=None),
#  Row(match_id='58532874-1474-4d29-bcb2-c6e0fb01f0ad', map_id='cebd854f-f206-11e4-b46e-24be05e24f7e', name='Coliseum', description='Forerunner Warrior-Servants tested themselves in this arena before facing the Flood.', is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 5, 9), match_duration=None),
#  Row(match_id='cbf51d4c-701b-402a-9f35-0966a245420a', map_id='cebd854f-f206-11e4-b46e-24be05e24f7e', name='Coliseum', description='Forerunner Warrior-Servants tested themselves in this arena before facing the Flood.', is_team_game=True, playlist_id='c98949ae-60a8-43dc-85d7-0feb0b92e719', completion_date=datetime.date(2016, 3, 10), match_duration=None),
#  Row(match_id='71cf43e2-e03f-4bf7-a523-5ac11813d00c', map_id='cc040aa1-f206-11e4-a3e0-24be05e24f7e', name='Fathom', description='The UNSC explores Beta Gabriel’s vast oceans in hopes of recovering wreckage hidden in the crushing depths.', is_team_game=False, playlist_id='d0766624-dbd7-4536-ba39-2d890a6143a9', completion_date=datetime.date(2016, 2, 2), match_duration=None),
#  Row(match_id='20f07255-b056-451f-bb1a-700e0c1033f2', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 2, 29), match_duration=None),
#  Row(match_id='49b83c45-9631-4e02-a611-9b2c8dd88f59', map_id='ca737f8f-f206-11e4-a7e2-24be05e24f7e', name='Overgrowth', description='Nature has reclaimed this tomb of millions.', is_team_game=False, playlist_id='d0766624-dbd7-4536-ba39-2d890a6143a9', completion_date=datetime.date(2016, 2, 19), match_duration=None),
#  Row(match_id='3b4f4ebf-54c2-45c6-9784-5548f9fd4935', map_id='c7805740-f206-11e4-982c-24be05e24f7e', name='Glacier', description="Each of Halo's microclimates can be controlled with exacting precision.", is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 3, 27), match_duration=None),
#  Row(match_id='92f49506-13e5-4438-809a-f7d6f7f94264', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 12, 27), match_duration=None),
#  Row(match_id='9c881daa-e593-4b45-94f3-9ed3df7ab889', map_id='c96ff240-f206-11e4-b581-24be05e24f7e', name='Battle of Noctus', description='The Andesian government vowed to root the Insurrection from Noctus', is_team_game=True, playlist_id='b50c4dc2-6c86-4d79-aa8a-23a65da292c6', completion_date=datetime.date(2016, 3, 12), match_duration=None),
#  Row(match_id='505b509e-d618-43f8-9151-dbf1487c5335', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 2, 18), match_duration=None),
#  Row(match_id='923fd89f-aa41-416a-a695-d445ef20ef9b', map_id='c74c9d0f-f206-11e4-8330-24be05e24f7e', name='Alpine', description='These vistas are Forerunner mementos', is_team_game=True, playlist_id='892189e9-d712-4bdb-afa7-1ccab43fbed4', completion_date=datetime.date(2016, 1, 26), match_duration=None),
#  Row(match_id='2f22aeb1-bcc8-4f7d-99e9-9c56089ef274', map_id='c74c9d0f-f206-11e4-8330-24be05e24f7e', name='Alpine', description='These vistas are Forerunner mementos', is_team_game=True, playlist_id='0bcf2be1-3168-4e42-9fb5-3551d7dbce77', completion_date=datetime.date(2015, 11, 28), match_duration=None),
#  Row(match_id='99b26b31-5d0c-4b95-a703-d06923bbd500', map_id='c96ff240-f206-11e4-b581-24be05e24f7e', name='Battle of Noctus', description='The Andesian government vowed to root the Insurrection from Noctus', is_team_game=True, playlist_id='b617e24f-71aa-432b-a8a0-a9b417a3d47e', completion_date=datetime.date(2016, 4, 3), match_duration=None),
#  Row(match_id='7541974d-b8a2-4df1-abcb-61097454cc55', map_id='cb251c51-f206-11e4-8541-24be05e24f7e', name='Raid on Apex 7', description='This unbroken ring is a symbol of the discovery that shook the galaxy and changed the course of both human and Covenant destiny.', is_team_game=True, playlist_id='b50c4dc2-6c86-4d79-aa8a-23a65da292c6', completion_date=datetime.date(2016, 2, 19), match_duration=None),
#  Row(match_id='7f81433a-6f9c-4ec8-bbac-bc110f9ca96e', map_id='c7805740-f206-11e4-982c-24be05e24f7e', name='Glacier', description="Each of Halo's microclimates can be controlled with exacting precision.", is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 2, 18), match_duration=None),
#  Row(match_id='3453a66d-6a56-434a-afa4-f6841972510f', map_id='cebd854f-f206-11e4-b46e-24be05e24f7e', name='Coliseum', description='Forerunner Warrior-Servants tested themselves in this arena before facing the Flood.', is_team_game=False, playlist_id='7b7e892c-d9b7-4b03-bef8-c6a071df28ef', completion_date=datetime.date(2015, 11, 25), match_duration=None),
#  Row(match_id='34b45a4e-d7e3-4c26-83bb-e9d3b88838a5', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 5, 3), match_duration=None),
#  Row(match_id='316baa2d-7fd7-4de5-b1dc-cdb6cb75880e', map_id='c7805740-f206-11e4-982c-24be05e24f7e', name='Glacier', description="Each of Halo's microclimates can be controlled with exacting precision.", is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 4, 3), match_duration=None),
#  Row(match_id='46f0490c-c100-45b6-8448-eb5f05efeb18', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 3, 27), match_duration=None),
#  Row(match_id='08187691-a14d-46db-bc37-505b451384a3', map_id='c96ff240-f206-11e4-b581-24be05e24f7e', name='Battle of Noctus', description='The Andesian government vowed to root the Insurrection from Noctus', is_team_game=True, playlist_id='b50c4dc2-6c86-4d79-aa8a-23a65da292c6', completion_date=datetime.date(2015, 12, 17), match_duration=None),
#  Row(match_id='a2953642-4444-4cb4-b84e-7aa6f04a302e', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 3, 27), match_duration=None),
#  Row(match_id='4eb96806-d435-40e5-a1ba-505248a17b28', map_id='ce1dc2de-f206-11e4-a646-24be05e24f7e', name='Truth', description=None, is_team_game=False, playlist_id='88b7de19-113c-4beb-af7f-8553aeda3f4c', completion_date=datetime.date(2015, 11, 28), match_duration=None),
#  Row(match_id='a2784240-a2eb-4917-96c2-5599bdef1138', map_id='cebd854f-f206-11e4-b46e-24be05e24f7e', name='Coliseum', description='Forerunner Warrior-Servants tested themselves in this arena before facing the Flood.', is_team_game=True, playlist_id='892189e9-d712-4bdb-afa7-1ccab43fbed4', completion_date=datetime.date(2016, 1, 8), match_duration=None),
#  Row(match_id='aeb40275-20b3-4c7b-a8ea-43bed58b3461', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=None, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 1, 24), match_duration=None),
#  Row(match_id='2b1f813c-74d7-4942-9a31-447a6e8b6818', map_id='c7805740-f206-11e4-982c-24be05e24f7e', name='Glacier', description="Each of Halo's microclimates can be controlled with exacting precision.", is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 3, 28), match_duration=None),
#  Row(match_id='676b5330-4023-4ec8-89e5-9910301abc7d', map_id='cebd854f-f206-11e4-b46e-24be05e24f7e', name='Coliseum', description='Forerunner Warrior-Servants tested themselves in this arena before facing the Flood.', is_team_game=False, playlist_id='88b7de19-113c-4beb-af7f-8553aeda3f4c', completion_date=datetime.date(2015, 11, 28), match_duration=None),
#  Row(match_id='bbbe0a65-77c2-435b-b8dd-b3d6ca4dfbd6', map_id='cdb934b0-f206-11e4-8810-24be05e24f7e', name='Empire', description='Military-industrial concerns that power the UNSC war machine are prime targets for Insurrection factions.', is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 4, 15), match_duration=None),
#  Row(match_id='d870936f-bb71-4799-9452-17f0990b8578', map_id='caacb800-f206-11e4-81ab-24be05e24f7e', name='Plaza', description='Promesa’s streets were no stranger to organized violence.', is_team_game=True, playlist_id='5728f612-3f20-4459-98bd-3478c79c4861', completion_date=datetime.date(2015, 12, 28), match_duration=None),
#  Row(match_id='c343a5ec-c270-498d-b81a-dc9a7ff04339', map_id='cdee4e70-f206-11e4-87a2-24be05e24f7e', name='Regret', description=None, is_team_game=True, playlist_id='c98949ae-60a8-43dc-85d7-0feb0b92e719', completion_date=datetime.date(2016, 1, 25), match_duration=None),
#  Row(match_id='b0772b1e-dd3e-4e50-9e40-e6ef6485d84a', map_id='cdee4e70-f206-11e4-87a2-24be05e24f7e', name='Regret', description=None, is_team_game=False, playlist_id='d0766624-dbd7-4536-ba39-2d890a6143a9', completion_date=datetime.date(2016, 2, 1), match_duration=None),
#  Row(match_id='2ddc9272-8a91-4aba-88f0-c9e97ebe6885', map_id='cc040aa1-f206-11e4-a3e0-24be05e24f7e', name='Fathom', description='The UNSC explores Beta Gabriel’s vast oceans in hopes of recovering wreckage hidden in the crushing depths.', is_team_game=True, playlist_id='c98949ae-60a8-43dc-85d7-0feb0b92e719', completion_date=datetime.date(2016, 5, 9), match_duration=None),
#  Row(match_id='b930af3c-d1be-4df9-a82f-c7106abb447e', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 1, 15), match_duration=None),
#  Row(match_id='b5f42b9f-c454-47d8-80ab-595316e21e45', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 1, 11), match_duration=None),
#  Row(match_id='4c9e19a8-8edc-44f7-912f-b1954294458a', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2016, 3, 28), match_duration=None),
#  Row(match_id='9781e555-188d-4efe-add8-697a2f9c4a36', map_id='cd844200-f206-11e4-9393-24be05e24f7e', name='Eden', description='Only now - years after the Human-Covenant War - do many Andesian citizens feel secure enough to return to the metroplex centers.', is_team_game=True, playlist_id='2323b76a-db98-4e03-aa37-e171cfbdd1a4', completion_date=datetime.date(2016, 5, 4), match_duration=None),
#  Row(match_id='2e77c48e-8aaf-40e5-bb5e-7eb01b86de84', map_id='c7edbf0f-f206-11e4-aa52-24be05e24f7e', name='Breakout Arena', description='The broadcast of Breakout matches has proven immensely popular with the UNSC Infinity crew.', is_team_game=True, playlist_id='f72e0ef0-7c4a-4307-af78-8e38dac3fdba', completion_date=datetime.date(2015, 11, 8), match_duration=None),
#  ...]

# %%
# Match Details

spark.sql("""DROP TABLE IF EXISTS bootcamp.match_details_bucketed""")

match_details_bucketedDDL = """
 CREATE TABLE IF NOT EXISTS bootcamp.match_details_bucketed (
     match_id STRING,
     player_gamertag STRING,
     player_total_kills INTEGER,
     player_total_deaths INTEGER
 )
 USING iceberg
 PARTITIONED BY (bucket(16, match_id));
"""

spark.sql(match_details_bucketedDDL)

match_details.select(col("match_id"), col("player_gamertag"), col("player_total_kills"), col("player_total_deaths")) \
     .write.mode("append") \
     .bucketBy(16, "match_id").saveAsTable("bootcamp.match_details_bucketed")

# %%
spark.sql("""SELECT * FROM bootcamp.match_details_bucketed""").collect()
# Out:
# [Row(match_id='f8852913-2ccf-46f6-a546-5578036144a9', player_gamertag='OneWingKing', player_total_kills=7, player_total_deaths=6),
#  Row(match_id='155cfd23-4f97-4f1b-b491-02cb5e7563b3', player_gamertag='BigChubSmith', player_total_kills=15, player_total_deaths=11),
#  Row(match_id='155cfd23-4f97-4f1b-b491-02cb5e7563b3', player_gamertag='JakeWilson801', player_total_kills=18, player_total_deaths=9),
#  Row(match_id='155cfd23-4f97-4f1b-b491-02cb5e7563b3', player_gamertag='taterbase', player_total_kills=1, player_total_deaths=12),
#  Row(match_id='155cfd23-4f97-4f1b-b491-02cb5e7563b3', player_gamertag='BeyondHumanx39', player_total_kills=13, player_total_deaths=14),
#  Row(match_id='155cfd23-4f97-4f1b-b491-02cb5e7563b3', player_gamertag='Twinsnakes05', player_total_kills=16, player_total_deaths=11),
#  Row(match_id='155cfd23-4f97-4f1b-b491-02cb5e7563b3', player_gamertag='Maverick62011', player_total_kills=9, player_total_deaths=14),
#  Row(match_id='155cfd23-4f97-4f1b-b491-02cb5e7563b3', player_gamertag='EcZachly', player_total_kills=16, player_total_deaths=16),
#  Row(match_id='155cfd23-4f97-4f1b-b491-02cb5e7563b3', player_gamertag='WhiteSpic', player_total_kills=10, player_total_deaths=12),
#  Row(match_id='b8d81721-befb-4274-a8ea-a4b1e8b6dd33', player_gamertag='JakeWilson801', player_total_kills=16, player_total_deaths=9),
#  Row(match_id='b8d81721-befb-4274-a8ea-a4b1e8b6dd33', player_gamertag='taterbase', player_total_kills=3, player_total_deaths=13),
#  Row(match_id='b8d81721-befb-4274-a8ea-a4b1e8b6dd33', player_gamertag='EcZachly', player_total_kills=19, player_total_deaths=14),
#  Row(match_id='b8d81721-befb-4274-a8ea-a4b1e8b6dd33', player_gamertag='cLaPPeD xo', player_total_kills=11, player_total_deaths=15),
#  Row(match_id='b8d81721-befb-4274-a8ea-a4b1e8b6dd33', player_gamertag='Nawsked', player_total_kills=12, player_total_deaths=14),
#  Row(match_id='b8d81721-befb-4274-a8ea-a4b1e8b6dd33', player_gamertag='iVaughn', player_total_kills=14, player_total_deaths=12),
#  Row(match_id='b8d81721-befb-4274-a8ea-a4b1e8b6dd33', player_gamertag='Roy Dossey', player_total_kills=13, player_total_deaths=11),
#  Row(match_id='b8d81721-befb-4274-a8ea-a4b1e8b6dd33', player_gamertag='Confustion', player_total_kills=11, player_total_deaths=12),
#  Row(match_id='c0c3daed-ad92-48e6-8734-b8476bab6b59', player_gamertag='SnipedI', player_total_kills=6, player_total_deaths=6),
#  Row(match_id='c0c3daed-ad92-48e6-8734-b8476bab6b59', player_gamertag='Clappage', player_total_kills=9, player_total_deaths=4),
#  Row(match_id='c0c3daed-ad92-48e6-8734-b8476bab6b59', player_gamertag='EcZachly', player_total_kills=8, player_total_deaths=5),
#  Row(match_id='c0c3daed-ad92-48e6-8734-b8476bab6b59', player_gamertag='Stormbane321', player_total_kills=3, player_total_deaths=8),
#  Row(match_id='c0c3daed-ad92-48e6-8734-b8476bab6b59', player_gamertag='l SUBZ3R0 l', player_total_kills=7, player_total_deaths=5),
#  Row(match_id='c0c3daed-ad92-48e6-8734-b8476bab6b59', player_gamertag='Mark SIII 313', player_total_kills=1, player_total_deaths=8),
#  Row(match_id='c0c3daed-ad92-48e6-8734-b8476bab6b59', player_gamertag='Oh So CrtkL', player_total_kills=7, player_total_deaths=5),
#  Row(match_id='c0c3daed-ad92-48e6-8734-b8476bab6b59', player_gamertag='Mane The Thang', player_total_kills=3, player_total_deaths=4),
#  Row(match_id='d7c54581-dfa8-458b-a172-2f41e937045e', player_gamertag='MunaMoney', player_total_kills=9, player_total_deaths=13),
#  Row(match_id='d7c54581-dfa8-458b-a172-2f41e937045e', player_gamertag='Ghost NotesS', player_total_kills=12, player_total_deaths=10),
#  Row(match_id='d7c54581-dfa8-458b-a172-2f41e937045e', player_gamertag='EcZachly', player_total_kills=15, player_total_deaths=13),
#  Row(match_id='d7c54581-dfa8-458b-a172-2f41e937045e', player_gamertag='Ooo NO FEAR ooO', player_total_kills=15, player_total_deaths=9),
#  Row(match_id='7d824b0f-4788-4bd3-a1b7-2eb72bd10a89', player_gamertag='HotLikeTamales', player_total_kills=6, player_total_deaths=12),
#  Row(match_id='d7c54581-dfa8-458b-a172-2f41e937045e', player_gamertag='My Regret', player_total_kills=6, player_total_deaths=8),
#  Row(match_id='d7c54581-dfa8-458b-a172-2f41e937045e', player_gamertag='x Davieboy x', player_total_kills=3, player_total_deaths=11),
#  Row(match_id='d7c54581-dfa8-458b-a172-2f41e937045e', player_gamertag='LUKEaUrOrA', player_total_kills=7, player_total_deaths=13),
#  Row(match_id='235d81fa-a6a4-41b2-ac37-383b63551795', player_gamertag='MrPart2', player_total_kills=22, player_total_deaths=14),
#  Row(match_id='235d81fa-a6a4-41b2-ac37-383b63551795', player_gamertag='EcZachly', player_total_kills=25, player_total_deaths=18),
#  Row(match_id='235d81fa-a6a4-41b2-ac37-383b63551795', player_gamertag='iDgAf cALi', player_total_kills=16, player_total_deaths=19),
#  Row(match_id='235d81fa-a6a4-41b2-ac37-383b63551795', player_gamertag='lamb of godII7', player_total_kills=12, player_total_deaths=18),
#  Row(match_id='235d81fa-a6a4-41b2-ac37-383b63551795', player_gamertag='II N E K R O X', player_total_kills=18, player_total_deaths=16),
#  Row(match_id='235d81fa-a6a4-41b2-ac37-383b63551795', player_gamertag='MagAndrew14', player_total_kills=17, player_total_deaths=25),
#  Row(match_id='c960df96-05a9-4d85-9d30-52fb8474233d', player_gamertag='Fair Is Fowl', player_total_kills=11, player_total_deaths=27),
#  Row(match_id='c960df96-05a9-4d85-9d30-52fb8474233d', player_gamertag='xNatey ICEx', player_total_kills=22, player_total_deaths=20),
#  Row(match_id='c960df96-05a9-4d85-9d30-52fb8474233d', player_gamertag='Stormbane321', player_total_kills=29, player_total_deaths=20),
#  Row(match_id='c960df96-05a9-4d85-9d30-52fb8474233d', player_gamertag='SluiceS', player_total_kills=17, player_total_deaths=19),
#  Row(match_id='c960df96-05a9-4d85-9d30-52fb8474233d', player_gamertag='ltem 9ine', player_total_kills=15, player_total_deaths=19),
#  Row(match_id='c960df96-05a9-4d85-9d30-52fb8474233d', player_gamertag='EcZachly', player_total_kills=13, player_total_deaths=23),
#  Row(match_id='c960df96-05a9-4d85-9d30-52fb8474233d', player_gamertag='ANDY FR3SH', player_total_kills=28, player_total_deaths=9),
#  Row(match_id='c960df96-05a9-4d85-9d30-52fb8474233d', player_gamertag='MrCleanUpDotCom', player_total_kills=21, player_total_deaths=19),
#  Row(match_id='226da37d-bf4b-498c-b119-14fc167a1f74', player_gamertag='JesseGodly', player_total_kills=10, player_total_deaths=8),
#  Row(match_id='226da37d-bf4b-498c-b119-14fc167a1f74', player_gamertag='H5 Doubles', player_total_kills=8, player_total_deaths=9),
#  Row(match_id='226da37d-bf4b-498c-b119-14fc167a1f74', player_gamertag='Stormbane321', player_total_kills=9, player_total_deaths=10),
#  Row(match_id='226da37d-bf4b-498c-b119-14fc167a1f74', player_gamertag='EcZachly', player_total_kills=1, player_total_deaths=9),
#  Row(match_id='8e250737-069f-4bc2-a00c-26b3d484651a', player_gamertag='FillBillsMilWil', player_total_kills=12, player_total_deaths=19),
#  Row(match_id='8e250737-069f-4bc2-a00c-26b3d484651a', player_gamertag='xxJohnnyRebelxx', player_total_kills=14, player_total_deaths=9),
#  Row(match_id='8e250737-069f-4bc2-a00c-26b3d484651a', player_gamertag='SWATsoldier07', player_total_kills=17, player_total_deaths=17),
#  Row(match_id='8e250737-069f-4bc2-a00c-26b3d484651a', player_gamertag='Bodacious Beanz', player_total_kills=12, player_total_deaths=16),
#  Row(match_id='8e250737-069f-4bc2-a00c-26b3d484651a', player_gamertag='Stormbane321', player_total_kills=15, player_total_deaths=10),
#  Row(match_id='8e250737-069f-4bc2-a00c-26b3d484651a', player_gamertag='Big Bulta559', player_total_kills=16, player_total_deaths=14),
#  Row(match_id='8e250737-069f-4bc2-a00c-26b3d484651a', player_gamertag='GodBlessWildBil', player_total_kills=9, player_total_deaths=13),
#  Row(match_id='8e250737-069f-4bc2-a00c-26b3d484651a', player_gamertag='EcZachly', player_total_kills=16, player_total_deaths=13),
#  Row(match_id='a8a56f75-ded0-4a91-83be-f67513460273', player_gamertag='Mass Murdaruh', player_total_kills=6, player_total_deaths=13),
#  Row(match_id='a8a56f75-ded0-4a91-83be-f67513460273', player_gamertag='Siriussss', player_total_kills=15, player_total_deaths=3),
#  Row(match_id='a8a56f75-ded0-4a91-83be-f67513460273', player_gamertag='W00YM00Y', player_total_kills=10, player_total_deaths=6),
#  Row(match_id='a8a56f75-ded0-4a91-83be-f67513460273', player_gamertag='JakeWilson801', player_total_kills=8, player_total_deaths=14),
#  Row(match_id='a8a56f75-ded0-4a91-83be-f67513460273', player_gamertag='EcZachly', player_total_kills=3, player_total_deaths=13),
#  Row(match_id='a8a56f75-ded0-4a91-83be-f67513460273', player_gamertag='Civiction', player_total_kills=11, player_total_deaths=6),
#  Row(match_id='a8a56f75-ded0-4a91-83be-f67513460273', player_gamertag='Floofy', player_total_kills=14, player_total_deaths=7),
#  Row(match_id='a8a56f75-ded0-4a91-83be-f67513460273', player_gamertag='Symbolic Syn', player_total_kills=5, player_total_deaths=10),
#  Row(match_id='951e409d-25a3-42b8-a38d-d3574da8f577', player_gamertag='EcZachly', player_total_kills=9, player_total_deaths=4),
#  Row(match_id='951e409d-25a3-42b8-a38d-d3574da8f577', player_gamertag='Glory Amplify', player_total_kills=4, player_total_deaths=11),
#  Row(match_id='951e409d-25a3-42b8-a38d-d3574da8f577', player_gamertag='SaVoR JaY', player_total_kills=5, player_total_deaths=14),
#  Row(match_id='951e409d-25a3-42b8-a38d-d3574da8f577', player_gamertag='Stormbane321', player_total_kills=16, player_total_deaths=5),
#  Row(match_id='7d824b0f-4788-4bd3-a1b7-2eb72bd10a89', player_gamertag='JakeWilson801', player_total_kills=14, player_total_deaths=9),
#  Row(match_id='7d824b0f-4788-4bd3-a1b7-2eb72bd10a89', player_gamertag='ChurroBear', player_total_kills=6, player_total_deaths=16),
#  Row(match_id='7d824b0f-4788-4bd3-a1b7-2eb72bd10a89', player_gamertag='TeamJustBringIt', player_total_kills=14, player_total_deaths=12),
#  Row(match_id='7d824b0f-4788-4bd3-a1b7-2eb72bd10a89', player_gamertag='Ash All Mighty', player_total_kills=12, player_total_deaths=9),
#  Row(match_id='7d824b0f-4788-4bd3-a1b7-2eb72bd10a89', player_gamertag='Masterbro47', player_total_kills=6, player_total_deaths=12),
#  Row(match_id='7d824b0f-4788-4bd3-a1b7-2eb72bd10a89', player_gamertag='EcZachly', player_total_kills=10, player_total_deaths=7),
#  Row(match_id='7d824b0f-4788-4bd3-a1b7-2eb72bd10a89', player_gamertag='Symbolic Syn', player_total_kills=15, player_total_deaths=7),
#  Row(match_id='c184e81c-ff3f-4787-b62f-3a02cf243b1d', player_gamertag='I Cubed', player_total_kills=12, player_total_deaths=11),
#  Row(match_id='c184e81c-ff3f-4787-b62f-3a02cf243b1d', player_gamertag='EcZachly', player_total_kills=13, player_total_deaths=14),
#  Row(match_id='c184e81c-ff3f-4787-b62f-3a02cf243b1d', player_gamertag='SaucyLady617', player_total_kills=16, player_total_deaths=9),
#  Row(match_id='c184e81c-ff3f-4787-b62f-3a02cf243b1d', player_gamertag='Wapanator', player_total_kills=6, player_total_deaths=14),
#  Row(match_id='c714976b-b5d2-49fb-9a7d-f6f334a4200d', player_gamertag='Doc Rendezvous', player_total_kills=3, player_total_deaths=7),
#  Row(match_id='c714976b-b5d2-49fb-9a7d-f6f334a4200d', player_gamertag='danmc33', player_total_kills=3, player_total_deaths=7),
#  Row(match_id='c714976b-b5d2-49fb-9a7d-f6f334a4200d', player_gamertag='CP Heretic', player_total_kills=11, player_total_deaths=2),
#  Row(match_id='c714976b-b5d2-49fb-9a7d-f6f334a4200d', player_gamertag='Symbolic Syn', player_total_kills=7, player_total_deaths=3),
#  Row(match_id='c714976b-b5d2-49fb-9a7d-f6f334a4200d', player_gamertag='sypxbox', player_total_kills=7, player_total_deaths=5),
#  Row(match_id='c714976b-b5d2-49fb-9a7d-f6f334a4200d', player_gamertag='ThrustDeeb0', player_total_kills=5, player_total_deaths=8),
#  Row(match_id='c714976b-b5d2-49fb-9a7d-f6f334a4200d', player_gamertag='EcZachly', player_total_kills=5, player_total_deaths=3),
#  Row(match_id='c714976b-b5d2-49fb-9a7d-f6f334a4200d', player_gamertag='SharkoThaDon88', player_total_kills=2, player_total_deaths=8),
#  Row(match_id='439073a2-71b7-452a-b7d4-7d399152357c', player_gamertag='EcZachly', player_total_kills=7, player_total_deaths=6),
#  Row(match_id='439073a2-71b7-452a-b7d4-7d399152357c', player_gamertag='Spartanwolf92', player_total_kills=7, player_total_deaths=7),
#  Row(match_id='439073a2-71b7-452a-b7d4-7d399152357c', player_gamertag='HashtagiPhone6', player_total_kills=9, player_total_deaths=6),
#  Row(match_id='439073a2-71b7-452a-b7d4-7d399152357c', player_gamertag='St Sarcasm', player_total_kills=2, player_total_deaths=6),
#  Row(match_id='439073a2-71b7-452a-b7d4-7d399152357c', player_gamertag='AsG RaGna', player_total_kills=8, player_total_deaths=5),
#  Row(match_id='439073a2-71b7-452a-b7d4-7d399152357c', player_gamertag='SnatchedWorm459', player_total_kills=3, player_total_deaths=8),
#  Row(match_id='439073a2-71b7-452a-b7d4-7d399152357c', player_gamertag='butterblack ops', player_total_kills=9, player_total_deaths=6),
#  Row(match_id='439073a2-71b7-452a-b7d4-7d399152357c', player_gamertag='RyansWorld19', player_total_kills=3, player_total_deaths=4),
#  Row(match_id='b3574aa9-8f2a-4697-859a-7b5bd2d57ecf', player_gamertag='BC Keenoid', player_total_kills=20, player_total_deaths=8),
#  Row(match_id='b3574aa9-8f2a-4697-859a-7b5bd2d57ecf', player_gamertag='JakeWilson801', player_total_kills=5, player_total_deaths=19),
#  Row(match_id='b3574aa9-8f2a-4697-859a-7b5bd2d57ecf', player_gamertag='TheManBLAZE', player_total_kills=8, player_total_deaths=7),
#  Row(match_id='b3574aa9-8f2a-4697-859a-7b5bd2d57ecf', player_gamertag='vxv mstodon vxv', player_total_kills=6, player_total_deaths=12),
#  Row(match_id='b3574aa9-8f2a-4697-859a-7b5bd2d57ecf', player_gamertag='Ignatius014', player_total_kills=4, player_total_deaths=8),
#  Row(match_id='b3574aa9-8f2a-4697-859a-7b5bd2d57ecf', player_gamertag='XtieQ', player_total_kills=11, player_total_deaths=4),
#  Row(match_id='b3574aa9-8f2a-4697-859a-7b5bd2d57ecf', player_gamertag='EcZachly', player_total_kills=13, player_total_deaths=11),
#  Row(match_id='b3574aa9-8f2a-4697-859a-7b5bd2d57ecf', player_gamertag='a tiney bAbY', player_total_kills=11, player_total_deaths=9),
#  Row(match_id='ca5ee130-8b52-4fd7-87d1-bb6131e93711', player_gamertag='MiracleAnt123', player_total_kills=9, player_total_deaths=18),
#  Row(match_id='ca5ee130-8b52-4fd7-87d1-bb6131e93711', player_gamertag='eliteone11', player_total_kills=12, player_total_deaths=13),
#  Row(match_id='ca5ee130-8b52-4fd7-87d1-bb6131e93711', player_gamertag='butterblack ops', player_total_kills=5, player_total_deaths=17),
#  Row(match_id='ca5ee130-8b52-4fd7-87d1-bb6131e93711', player_gamertag='EcZachly', player_total_kills=19, player_total_deaths=10),
#  Row(match_id='ca5ee130-8b52-4fd7-87d1-bb6131e93711', player_gamertag='Aldo Bass', player_total_kills=23, player_total_deaths=15),
#  Row(match_id='ca5ee130-8b52-4fd7-87d1-bb6131e93711', player_gamertag='Heff228', player_total_kills=11, player_total_deaths=11),
#  Row(match_id='ca5ee130-8b52-4fd7-87d1-bb6131e93711', player_gamertag='Godly Botchy', player_total_kills=20, player_total_deaths=14),
#  Row(match_id='ca5ee130-8b52-4fd7-87d1-bb6131e93711', player_gamertag='ViaticOregon530', player_total_kills=0, player_total_deaths=0),
#  Row(match_id='8c783fb3-2769-43d8-9a6f-b7e9bb3aebea', player_gamertag='DandyRazlo', player_total_kills=11, player_total_deaths=5),
#  Row(match_id='8c783fb3-2769-43d8-9a6f-b7e9bb3aebea', player_gamertag='EcZachly', player_total_kills=3, player_total_deaths=8),
#  Row(match_id='8c783fb3-2769-43d8-9a6f-b7e9bb3aebea', player_gamertag='A1ex08', player_total_kills=5, player_total_deaths=5),
#  Row(match_id='8c783fb3-2769-43d8-9a6f-b7e9bb3aebea', player_gamertag='Frustracean', player_total_kills=10, player_total_deaths=5),
#  Row(match_id='8c783fb3-2769-43d8-9a6f-b7e9bb3aebea', player_gamertag='Konsti313', player_total_kills=3, player_total_deaths=6),
#  Row(match_id='8c783fb3-2769-43d8-9a6f-b7e9bb3aebea', player_gamertag='NicoBullet261', player_total_kills=2, player_total_deaths=6),
#  Row(match_id='8c783fb3-2769-43d8-9a6f-b7e9bb3aebea', player_gamertag='Wapanator', player_total_kills=10, player_total_deaths=6),
#  Row(match_id='8c783fb3-2769-43d8-9a6f-b7e9bb3aebea', player_gamertag='Nightwolf0601', player_total_kills=0, player_total_deaths=6),
#  Row(match_id='77819f07-52fe-4296-bb8e-5060db126a8e', player_gamertag='Monte7O35O', player_total_kills=4, player_total_deaths=6),
#  Row(match_id='77819f07-52fe-4296-bb8e-5060db126a8e', player_gamertag='ll Corvus ll', player_total_kills=5, player_total_deaths=5),
#  Row(match_id='77819f07-52fe-4296-bb8e-5060db126a8e', player_gamertag='EcZachly', player_total_kills=10, player_total_deaths=3),
#  Row(match_id='77819f07-52fe-4296-bb8e-5060db126a8e', player_gamertag='zXSilentEchoXz', player_total_kills=7, player_total_deaths=3),
#  Row(match_id='77819f07-52fe-4296-bb8e-5060db126a8e', player_gamertag='butterblack ops', player_total_kills=6, player_total_deaths=7),
#  Row(match_id='77819f07-52fe-4296-bb8e-5060db126a8e', player_gamertag='I Am Yoda Man99', player_total_kills=2, player_total_deaths=6),
#  Row(match_id='77819f07-52fe-4296-bb8e-5060db126a8e', player_gamertag='Glatix', player_total_kills=5, player_total_deaths=7),
#  Row(match_id='77819f07-52fe-4296-bb8e-5060db126a8e', player_gamertag='AidanPro1892', player_total_kills=5, player_total_deaths=7),
#  Row(match_id='af7f7136-cf1c-4f2a-9a24-be78325f8619', player_gamertag='Sebastiencorps', player_total_kills=4, player_total_deaths=7),
#  Row(match_id='af7f7136-cf1c-4f2a-9a24-be78325f8619', player_gamertag='butterblack ops', player_total_kills=6, player_total_deaths=6),
#  Row(match_id='af7f7136-cf1c-4f2a-9a24-be78325f8619', player_gamertag='EcZachly', player_total_kills=9, player_total_deaths=5),
#  Row(match_id='af7f7136-cf1c-4f2a-9a24-be78325f8619', player_gamertag='HaloXFan', player_total_kills=5, player_total_deaths=5),
#  Row(match_id='af7f7136-cf1c-4f2a-9a24-be78325f8619', player_gamertag='xSPARTANGEAR1x', player_total_kills=3, player_total_deaths=8),
#  Row(match_id='af7f7136-cf1c-4f2a-9a24-be78325f8619', player_gamertag='GoldenPatriot15', player_total_kills=1, player_total_deaths=7),
#  Row(match_id='af7f7136-cf1c-4f2a-9a24-be78325f8619', player_gamertag='Crazydavid 7212', player_total_kills=12, player_total_deaths=6),
#  Row(match_id='af7f7136-cf1c-4f2a-9a24-be78325f8619', player_gamertag='FS Shadow Wolf', player_total_kills=8, player_total_deaths=6),
#  Row(match_id='4355cd25-a141-4935-91d0-385935db857a', player_gamertag='handicap99', player_total_kills=3, player_total_deaths=5),
#  Row(match_id='4355cd25-a141-4935-91d0-385935db857a', player_gamertag='EcZachly', player_total_kills=8, player_total_deaths=5),
#  Row(match_id='4355cd25-a141-4935-91d0-385935db857a', player_gamertag='ILLICIT 117', player_total_kills=2, player_total_deaths=7),
#  Row(match_id='4355cd25-a141-4935-91d0-385935db857a', player_gamertag='SpenceRAWR', player_total_kills=3, player_total_deaths=6),
#  Row(match_id='4355cd25-a141-4935-91d0-385935db857a', player_gamertag='IVDot Dr', player_total_kills=11, player_total_deaths=2),
#  Row(match_id='4355cd25-a141-4935-91d0-385935db857a', player_gamertag='Mens Pulchra', player_total_kills=3, player_total_deaths=6),
#  Row(match_id='4355cd25-a141-4935-91d0-385935db857a', player_gamertag='S1k SH07z', player_total_kills=3, player_total_deaths=7),
#  Row(match_id='4355cd25-a141-4935-91d0-385935db857a', player_gamertag='Euippe', player_total_kills=7, player_total_deaths=3),
#  Row(match_id='59c34e38-10ca-4dd9-a12b-cdfeb698e8b9', player_gamertag='CRACKY 4', player_total_kills=9, player_total_deaths=12),
#  Row(match_id='59c34e38-10ca-4dd9-a12b-cdfeb698e8b9', player_gamertag='Ash All Mighty', player_total_kills=11, player_total_deaths=6),
#  Row(match_id='59c34e38-10ca-4dd9-a12b-cdfeb698e8b9', player_gamertag='Legacy Of Link', player_total_kills=6, player_total_deaths=10),
#  Row(match_id='59c34e38-10ca-4dd9-a12b-cdfeb698e8b9', player_gamertag='Fjaxyu', player_total_kills=8, player_total_deaths=11),
#  Row(match_id='59c34e38-10ca-4dd9-a12b-cdfeb698e8b9', player_gamertag='UKK JOCK88', player_total_kills=12, player_total_deaths=14),
#  Row(match_id='59c34e38-10ca-4dd9-a12b-cdfeb698e8b9', player_gamertag='GBH Spitfire', player_total_kills=8, player_total_deaths=14),
#  Row(match_id='59c34e38-10ca-4dd9-a12b-cdfeb698e8b9', player_gamertag='EcZachly', player_total_kills=17, player_total_deaths=8),
#  Row(match_id='59c34e38-10ca-4dd9-a12b-cdfeb698e8b9', player_gamertag='Wapanator', player_total_kills=14, player_total_deaths=10),
#  Row(match_id='4687fc34-8482-4cff-a9ef-8804cffbda58', player_gamertag='Ash All Mighty', player_total_kills=3, player_total_deaths=6),
#  Row(match_id='4687fc34-8482-4cff-a9ef-8804cffbda58', player_gamertag='EcZachly', player_total_kills=3, player_total_deaths=6),
#  Row(match_id='4687fc34-8482-4cff-a9ef-8804cffbda58', player_gamertag='JakeWilson801', player_total_kills=4, player_total_deaths=6),
#  Row(match_id='4687fc34-8482-4cff-a9ef-8804cffbda58', player_gamertag='Cynical Spaded', player_total_kills=8, player_total_deaths=3),
#  Row(match_id='4687fc34-8482-4cff-a9ef-8804cffbda58', player_gamertag='IrIshThePro', player_total_kills=8, player_total_deaths=2),
#  Row(match_id='4687fc34-8482-4cff-a9ef-8804cffbda58', player_gamertag='A Lucent Eagle', player_total_kills=4, player_total_deaths=5),
#  Row(match_id='4687fc34-8482-4cff-a9ef-8804cffbda58', player_gamertag='ILLICIT 117', player_total_kills=3, player_total_deaths=5),
#  Row(match_id='4687fc34-8482-4cff-a9ef-8804cffbda58', player_gamertag='Preinitializing', player_total_kills=3, player_total_deaths=3),
#  Row(match_id='40bc5a53-6a17-4f57-a669-8a92a1123e0e', player_gamertag='Lil Frier', player_total_kills=17, player_total_deaths=11),
#  Row(match_id='40bc5a53-6a17-4f57-a669-8a92a1123e0e', player_gamertag='You Were Rekt', player_total_kills=13, player_total_deaths=10),
#  Row(match_id='40bc5a53-6a17-4f57-a669-8a92a1123e0e', player_gamertag='EcZachly', player_total_kills=8, player_total_deaths=12),
#  Row(match_id='40bc5a53-6a17-4f57-a669-8a92a1123e0e', player_gamertag='IxI Draco IxI', player_total_kills=15, player_total_deaths=8),
#  Row(match_id='40bc5a53-6a17-4f57-a669-8a92a1123e0e', player_gamertag='WHlax91', player_total_kills=12, player_total_deaths=12),
#  Row(match_id='40bc5a53-6a17-4f57-a669-8a92a1123e0e', player_gamertag='Foresaiyan', player_total_kills=9, player_total_deaths=14),
#  Row(match_id='40bc5a53-6a17-4f57-a669-8a92a1123e0e', player_gamertag='Vigilant Whale', player_total_kills=13, player_total_deaths=13),
#  Row(match_id='40bc5a53-6a17-4f57-a669-8a92a1123e0e', player_gamertag='Enders7', player_total_kills=14, player_total_deaths=13),
#  Row(match_id='86a3929b-d86e-4f8e-a158-4a7f608e39e4', player_gamertag='jealousofmy360', player_total_kills=7, player_total_deaths=12),
#  Row(match_id='86a3929b-d86e-4f8e-a158-4a7f608e39e4', player_gamertag='Kolorado11', player_total_kills=8, player_total_deaths=6),
#  Row(match_id='86a3929b-d86e-4f8e-a158-4a7f608e39e4', player_gamertag='JakeWilson801', player_total_kills=5, player_total_deaths=14),
#  Row(match_id='86a3929b-d86e-4f8e-a158-4a7f608e39e4', player_gamertag='RedCell258', player_total_kills=14, player_total_deaths=6),
#  Row(match_id='86a3929b-d86e-4f8e-a158-4a7f608e39e4', player_gamertag='EcZachly', player_total_kills=7, player_total_deaths=14),
#  Row(match_id='86a3929b-d86e-4f8e-a158-4a7f608e39e4', player_gamertag='Taiifox Emperor', player_total_kills=11, player_total_deaths=10),
#  Row(match_id='86a3929b-d86e-4f8e-a158-4a7f608e39e4', player_gamertag='ClutchMagoo', player_total_kills=13, player_total_deaths=6),
#  Row(match_id='86a3929b-d86e-4f8e-a158-4a7f608e39e4', player_gamertag='II KMACK II', player_total_kills=15, player_total_deaths=12),
#  Row(match_id='de523257-6c6d-43e7-976c-444ff8c9f0a0', player_gamertag='ihateapex17', player_total_kills=13, player_total_deaths=16),
#  Row(match_id='de523257-6c6d-43e7-976c-444ff8c9f0a0', player_gamertag='JakeWilson801', player_total_kills=8, player_total_deaths=11),
#  Row(match_id='de523257-6c6d-43e7-976c-444ff8c9f0a0', player_gamertag='EcZachly', player_total_kills=10, player_total_deaths=16),
#  Row(match_id='de523257-6c6d-43e7-976c-444ff8c9f0a0', player_gamertag='The Kid Fox', player_total_kills=18, player_total_deaths=7),
#  Row(match_id='de523257-6c6d-43e7-976c-444ff8c9f0a0', player_gamertag='XcobaltXghostX', player_total_kills=9, player_total_deaths=11),
#  Row(match_id='de523257-6c6d-43e7-976c-444ff8c9f0a0', player_gamertag='CrockedLeek', player_total_kills=10, player_total_deaths=9),
#  Row(match_id='de523257-6c6d-43e7-976c-444ff8c9f0a0', player_gamertag='ZoNe LeGeNDaRY', player_total_kills=16, player_total_deaths=9),
#  Row(match_id='de523257-6c6d-43e7-976c-444ff8c9f0a0', player_gamertag='I Enygmata I', player_total_kills=9, player_total_deaths=14),
#  Row(match_id='153114e1-3277-41f6-8664-2749e6aed844', player_gamertag='UncouthTarsier6', player_total_kills=8, player_total_deaths=15),
#  Row(match_id='153114e1-3277-41f6-8664-2749e6aed844', player_gamertag='LightTemple', player_total_kills=7, player_total_deaths=14),
#  Row(match_id='153114e1-3277-41f6-8664-2749e6aed844', player_gamertag='wrecker125', player_total_kills=4, player_total_deaths=12),
#  Row(match_id='153114e1-3277-41f6-8664-2749e6aed844', player_gamertag='EcZachly', player_total_kills=13, player_total_deaths=11),
#  Row(match_id='153114e1-3277-41f6-8664-2749e6aed844', player_gamertag='JakeWilson801', player_total_kills=13, player_total_deaths=8),
#  Row(match_id='153114e1-3277-41f6-8664-2749e6aed844', player_gamertag='Unreal Ace 15', player_total_kills=14, player_total_deaths=9),
#  Row(match_id='153114e1-3277-41f6-8664-2749e6aed844', player_gamertag='GearsCarnage M1', player_total_kills=16, player_total_deaths=9),
#  Row(match_id='153114e1-3277-41f6-8664-2749e6aed844', player_gamertag='ken j 08', player_total_kills=10, player_total_deaths=7),
#  Row(match_id='f5d052b9-1d90-42ab-b9a5-7ec613b44d43', player_gamertag='x FaVoLoUs x', player_total_kills=12, player_total_deaths=11),
#  Row(match_id='f5d052b9-1d90-42ab-b9a5-7ec613b44d43', player_gamertag='A Lazy Pickle', player_total_kills=14, player_total_deaths=9),
#  Row(match_id='f5d052b9-1d90-42ab-b9a5-7ec613b44d43', player_gamertag='Sosa oH', player_total_kills=14, player_total_deaths=11),
#  Row(match_id='f5d052b9-1d90-42ab-b9a5-7ec613b44d43', player_gamertag='GrizzzlyBearzz', player_total_kills=15, player_total_deaths=14),
#  Row(match_id='f5d052b9-1d90-42ab-b9a5-7ec613b44d43', player_gamertag='Infvrno', player_total_kills=12, player_total_deaths=12),
#  Row(match_id='f5d052b9-1d90-42ab-b9a5-7ec613b44d43', player_gamertag='I AM NUMBERWON', player_total_kills=12, player_total_deaths=8),
#  Row(match_id='f5d052b9-1d90-42ab-b9a5-7ec613b44d43', player_gamertag='EcZachly', player_total_kills=6, player_total_deaths=16),
#  Row(match_id='f5d052b9-1d90-42ab-b9a5-7ec613b44d43', player_gamertag='JOLLY 420 GREEN', player_total_kills=7, player_total_deaths=11),
#  Row(match_id='dc61e65d-11d0-4658-bc05-e7b63f77b26a', player_gamertag='andij117', player_total_kills=4, player_total_deaths=5),
#  Row(match_id='dc61e65d-11d0-4658-bc05-e7b63f77b26a', player_gamertag='EcZachly', player_total_kills=6, player_total_deaths=4),
#  Row(match_id='dc61e65d-11d0-4658-bc05-e7b63f77b26a', player_gamertag='Ash All Mighty', player_total_kills=12, player_total_deaths=2),
#  Row(match_id='dc61e65d-11d0-4658-bc05-e7b63f77b26a', player_gamertag='Saint167x', player_total_kills=6, player_total_deaths=5),
#  Row(match_id='dc61e65d-11d0-4658-bc05-e7b63f77b26a', player_gamertag='xXxWJB40xXx', player_total_kills=6, player_total_deaths=7),
#  Row(match_id='dc61e65d-11d0-4658-bc05-e7b63f77b26a', player_gamertag='luckynachos', player_total_kills=2, player_total_deaths=4),
#  Row(match_id='dc61e65d-11d0-4658-bc05-e7b63f77b26a', player_gamertag='AzN GaMeR 1', player_total_kills=0, player_total_deaths=7),
#  Row(match_id='dc61e65d-11d0-4658-bc05-e7b63f77b26a', player_gamertag='Blackaurora20', player_total_kills=4, player_total_deaths=6),
#  Row(match_id='538a7306-13ff-48b6-90c7-4335b7f217bb', player_gamertag='Mario Chief', player_total_kills=15, player_total_deaths=12),
#  Row(match_id='538a7306-13ff-48b6-90c7-4335b7f217bb', player_gamertag='ILLICIT 117', player_total_kills=11, player_total_deaths=16),
#  Row(match_id='538a7306-13ff-48b6-90c7-4335b7f217bb', player_gamertag='SufferedKR38z', player_total_kills=8, player_total_deaths=9),
#  Row(match_id='538a7306-13ff-48b6-90c7-4335b7f217bb', player_gamertag='EcZachly', player_total_kills=16, player_total_deaths=10),
#  Row(match_id='538a7306-13ff-48b6-90c7-4335b7f217bb', player_gamertag='mushroomstein', player_total_kills=19, player_total_deaths=12),
#  Row(match_id='538a7306-13ff-48b6-90c7-4335b7f217bb', player_gamertag='Meowing Cat 42', player_total_kills=7, player_total_deaths=14),
#  Row(match_id='538a7306-13ff-48b6-90c7-4335b7f217bb', player_gamertag='AshLikeWoah', player_total_kills=11, player_total_deaths=11),
#  Row(match_id='538a7306-13ff-48b6-90c7-4335b7f217bb', player_gamertag='Antonio8414', player_total_kills=10, player_total_deaths=13),
#  Row(match_id='c3ff4d86-b2e9-44dc-8b53-c102d59456bc', player_gamertag='VortexpluZ', player_total_kills=1, player_total_deaths=3),
#  Row(match_id='c3ff4d86-b2e9-44dc-8b53-c102d59456bc', player_gamertag='DiSc0gEnIe', player_total_kills=14, player_total_deaths=8),
#  Row(match_id='c3ff4d86-b2e9-44dc-8b53-c102d59456bc', player_gamertag='JSxAntiquated', player_total_kills=14, player_total_deaths=8),
#  Row(match_id='c3ff4d86-b2e9-44dc-8b53-c102d59456bc', player_gamertag='CrOwS Of DeAtH', player_total_kills=0, player_total_deaths=3),
#  Row(match_id='c3ff4d86-b2e9-44dc-8b53-c102d59456bc', player_gamertag='EcZachly', player_total_kills=8, player_total_deaths=12),
#  Row(match_id='c3ff4d86-b2e9-44dc-8b53-c102d59456bc', player_gamertag='Stormbane321', player_total_kills=13, player_total_deaths=13),
#  Row(match_id='c3ff4d86-b2e9-44dc-8b53-c102d59456bc', player_gamertag='Seft3l', player_total_kills=8, player_total_deaths=13),
#  Row(match_id='c3ff4d86-b2e9-44dc-8b53-c102d59456bc', player_gamertag='Ash All Mighty', player_total_kills=11, player_total_deaths=10),
#  Row(match_id='c3ff4d86-b2e9-44dc-8b53-c102d59456bc', player_gamertag='Fjaxyu', player_total_kills=9, player_total_deaths=10),
#  Row(match_id='c3ff4d86-b2e9-44dc-8b53-c102d59456bc', player_gamertag='Wapanator', player_total_kills=7, player_total_deaths=10),
#  Row(match_id='c3ff4d86-b2e9-44dc-8b53-c102d59456bc', player_gamertag='Cerial Killller', player_total_kills=10, player_total_deaths=9),
#  Row(match_id='c3ff4d86-b2e9-44dc-8b53-c102d59456bc', player_gamertag='KAWHI xLEONARD', player_total_kills=7, player_total_deaths=6),
#  Row(match_id='bd21cebe-d7b4-4673-bb84-87d2f2121f9a', player_gamertag='ILLICIT 117', player_total_kills=1, player_total_deaths=5),
#  Row(match_id='bd21cebe-d7b4-4673-bb84-87d2f2121f9a', player_gamertag='M0d3Rn WArR1oR', player_total_kills=3, player_total_deaths=2),
#  Row(match_id='bd21cebe-d7b4-4673-bb84-87d2f2121f9a', player_gamertag='Apex T Rex', player_total_kills=7, player_total_deaths=0),
#  Row(match_id='bd21cebe-d7b4-4673-bb84-87d2f2121f9a', player_gamertag='EcZachly', player_total_kills=2, player_total_deaths=5),
#  Row(match_id='bd21cebe-d7b4-4673-bb84-87d2f2121f9a', player_gamertag='iTz SHADOWSIFYx', player_total_kills=6, player_total_deaths=1),
#  Row(match_id='bd21cebe-d7b4-4673-bb84-87d2f2121f9a', player_gamertag='CyberPanther18', player_total_kills=2, player_total_deaths=5),
#  Row(match_id='bd21cebe-d7b4-4673-bb84-87d2f2121f9a', player_gamertag='M0SHISM', player_total_kills=4, player_total_deaths=2),
#  Row(match_id='bd21cebe-d7b4-4673-bb84-87d2f2121f9a', player_gamertag='Mr WillyFlynn', player_total_kills=0, player_total_deaths=5),
#  Row(match_id='72f00e60-a4ee-46fc-b8ab-7a5f8f621579', player_gamertag='Carbon Skys', player_total_kills=5, player_total_deaths=15),
#  Row(match_id='72f00e60-a4ee-46fc-b8ab-7a5f8f621579', player_gamertag='JakeWilson801', player_total_kills=13, player_total_deaths=6),
#  Row(match_id='72f00e60-a4ee-46fc-b8ab-7a5f8f621579', player_gamertag='BiGhungryMonstR', player_total_kills=10, player_total_deaths=7),
#  Row(match_id='72f00e60-a4ee-46fc-b8ab-7a5f8f621579', player_gamertag='YrinK iZ RiPPiN', player_total_kills=10, player_total_deaths=15),
#  Row(match_id='72f00e60-a4ee-46fc-b8ab-7a5f8f621579', player_gamertag='OMG PINEAPPLES', player_total_kills=9, player_total_deaths=13),
#  Row(match_id='72f00e60-a4ee-46fc-b8ab-7a5f8f621579', player_gamertag='PoooooKy', player_total_kills=11, player_total_deaths=10),
#  Row(match_id='72f00e60-a4ee-46fc-b8ab-7a5f8f621579', player_gamertag='EcZachly', player_total_kills=20, player_total_deaths=6),
#  Row(match_id='72f00e60-a4ee-46fc-b8ab-7a5f8f621579', player_gamertag='I Camelot', player_total_kills=6, player_total_deaths=10),
#  Row(match_id='0e5fbff1-9abb-4470-b77e-2cbff00aba25', player_gamertag='ILLICIT 117', player_total_kills=9, player_total_deaths=16),
#  Row(match_id='0e5fbff1-9abb-4470-b77e-2cbff00aba25', player_gamertag='DatDrumGameDoe', player_total_kills=5, player_total_deaths=11),
#  Row(match_id='0e5fbff1-9abb-4470-b77e-2cbff00aba25', player_gamertag='StaTIcBR34Kdown', player_total_kills=18, player_total_deaths=14),
#  Row(match_id='0e5fbff1-9abb-4470-b77e-2cbff00aba25', player_gamertag='YashirO UcHiiHa', player_total_kills=12, player_total_deaths=12),
#  Row(match_id='0e5fbff1-9abb-4470-b77e-2cbff00aba25', player_gamertag='snip3r uchiha', player_total_kills=8, player_total_deaths=13),
#  Row(match_id='0e5fbff1-9abb-4470-b77e-2cbff00aba25', player_gamertag='z IMidgeT z', player_total_kills=15, player_total_deaths=8),
#  Row(match_id='0e5fbff1-9abb-4470-b77e-2cbff00aba25', player_gamertag='All To Myself', player_total_kills=13, player_total_deaths=9),
#  Row(match_id='0e5fbff1-9abb-4470-b77e-2cbff00aba25', player_gamertag='EcZachly', player_total_kills=12, player_total_deaths=10),
#  Row(match_id='5925eeca-b23b-4f4b-8fb2-b9bd25e97875', player_gamertag='Ash All Mighty', player_total_kills=4, player_total_deaths=8),
#  Row(match_id='5925eeca-b23b-4f4b-8fb2-b9bd25e97875', player_gamertag='zjeepwatzup', player_total_kills=3, player_total_deaths=5),
#  Row(match_id='5925eeca-b23b-4f4b-8fb2-b9bd25e97875', player_gamertag='EcZachly', player_total_kills=9, player_total_deaths=6),
#  Row(match_id='5925eeca-b23b-4f4b-8fb2-b9bd25e97875', player_gamertag='NiCE WiDiT', player_total_kills=1, player_total_deaths=6),
#  Row(match_id='5925eeca-b23b-4f4b-8fb2-b9bd25e97875', player_gamertag='Siriussss', player_total_kills=8, player_total_deaths=4),
#  Row(match_id='5925eeca-b23b-4f4b-8fb2-b9bd25e97875', player_gamertag='GTy RoLD', player_total_kills=7, player_total_deaths=5),
#  Row(match_id='5925eeca-b23b-4f4b-8fb2-b9bd25e97875', player_gamertag='Dignifyed', player_total_kills=9, player_total_deaths=5),
#  Row(match_id='5925eeca-b23b-4f4b-8fb2-b9bd25e97875', player_gamertag='Adept Divinity', player_total_kills=4, player_total_deaths=6),
#  Row(match_id='baea5421-0e0c-40e5-9374-edaba786c88b', player_gamertag='Bumshy', player_total_kills=12, player_total_deaths=7),
#  Row(match_id='baea5421-0e0c-40e5-9374-edaba786c88b', player_gamertag='Reygulate', player_total_kills=16, player_total_deaths=5),
#  Row(match_id='baea5421-0e0c-40e5-9374-edaba786c88b', player_gamertag='Ash All Mighty', player_total_kills=6, player_total_deaths=12),
#  Row(match_id='baea5421-0e0c-40e5-9374-edaba786c88b', player_gamertag='My Regret', player_total_kills=13, player_total_deaths=8),
#  Row(match_id='baea5421-0e0c-40e5-9374-edaba786c88b', player_gamertag='eXpose ZayKo', player_total_kills=5, player_total_deaths=13),
#  Row(match_id='baea5421-0e0c-40e5-9374-edaba786c88b', player_gamertag='lightningcat117', player_total_kills=4, player_total_deaths=11),
#  Row(match_id='5033828d-3134-4cfa-a13e-fff5fc68316d', player_gamertag='ErrbaN Arrow', player_total_kills=7, player_total_deaths=11),
#  Row(match_id='5033828d-3134-4cfa-a13e-fff5fc68316d', player_gamertag='CPU lucky', player_total_kills=16, player_total_deaths=15),
#  Row(match_id='5033828d-3134-4cfa-a13e-fff5fc68316d', player_gamertag='El Rey del 117', player_total_kills=15, player_total_deaths=10),
#  Row(match_id='5033828d-3134-4cfa-a13e-fff5fc68316d', player_gamertag='HectorGamer2701', player_total_kills=12, player_total_deaths=12),
#  Row(match_id='5033828d-3134-4cfa-a13e-fff5fc68316d', player_gamertag='Investimagate', player_total_kills=18, player_total_deaths=15),
#  Row(match_id='5033828d-3134-4cfa-a13e-fff5fc68316d', player_gamertag='DJ R H 3', player_total_kills=0, player_total_deaths=3),
#  Row(match_id='5033828d-3134-4cfa-a13e-fff5fc68316d', player_gamertag='EcZachly', player_total_kills=14, player_total_deaths=14),
#  Row(match_id='5033828d-3134-4cfa-a13e-fff5fc68316d', player_gamertag='Rie Dawg', player_total_kills=16, player_total_deaths=18),
#  Row(match_id='baea5421-0e0c-40e5-9374-edaba786c88b', player_gamertag='EcZachly', player_total_kills=10, player_total_deaths=14),
#  Row(match_id='133f846e-20cb-4a9c-91c0-9eaa3a2ac071', player_gamertag='ILLICIT 117', player_total_kills=14, player_total_deaths=4),
#  Row(match_id='133f846e-20cb-4a9c-91c0-9eaa3a2ac071', player_gamertag='EcZachly', player_total_kills=2, player_total_deaths=6),
#  Row(match_id='133f846e-20cb-4a9c-91c0-9eaa3a2ac071', player_gamertag='ZER0 WS', player_total_kills=6, player_total_deaths=6),
#  Row(match_id='133f846e-20cb-4a9c-91c0-9eaa3a2ac071', player_gamertag='TypeRayx', player_total_kills=4, player_total_deaths=8),
#  Row(match_id='133f846e-20cb-4a9c-91c0-9eaa3a2ac071', player_gamertag='SACHIxBNG', player_total_kills=9, player_total_deaths=4),
#  Row(match_id='133f846e-20cb-4a9c-91c0-9eaa3a2ac071', player_gamertag='Cpt BubbleButt', player_total_kills=5, player_total_deaths=7),
#  Row(match_id='133f846e-20cb-4a9c-91c0-9eaa3a2ac071', player_gamertag='RiSeOfD4RkNeSS', player_total_kills=5, player_total_deaths=6),
#  Row(match_id='133f846e-20cb-4a9c-91c0-9eaa3a2ac071', player_gamertag='dLuX I ShotZz', player_total_kills=4, player_total_deaths=8),
#  Row(match_id='92f619c2-38b4-4d43-a228-d45d5f42f397', player_gamertag='WoodZeeOwl', player_total_kills=3, player_total_deaths=12),
#  Row(match_id='92f619c2-38b4-4d43-a228-d45d5f42f397', player_gamertag='Epson ZC36', player_total_kills=15, player_total_deaths=8),
#  Row(match_id='92f619c2-38b4-4d43-a228-d45d5f42f397', player_gamertag='Grundlz Got It', player_total_kills=7, player_total_deaths=7),
#  Row(match_id='92f619c2-38b4-4d43-a228-d45d5f42f397', player_gamertag='ZeMo iS SN', player_total_kills=12, player_total_deaths=2),
#  Row(match_id='92f619c2-38b4-4d43-a228-d45d5f42f397', player_gamertag='Lil Black BUBBA', player_total_kills=14, player_total_deaths=9),
#  Row(match_id='92f619c2-38b4-4d43-a228-d45d5f42f397', player_gamertag='Stormbane321', player_total_kills=8, player_total_deaths=15),
#  Row(match_id='92f619c2-38b4-4d43-a228-d45d5f42f397', player_gamertag='EcZachly', player_total_kills=9, player_total_deaths=16),
#  Row(match_id='92f619c2-38b4-4d43-a228-d45d5f42f397', player_gamertag='Lean Thy Bloke', player_total_kills=9, player_total_deaths=8),
#  Row(match_id='a7edd7e4-ecba-41fb-b507-0d9e37143917', player_gamertag='Lean Thy Bloke', player_total_kills=8, player_total_deaths=9),
#  Row(match_id='a7edd7e4-ecba-41fb-b507-0d9e37143917', player_gamertag='Stormbane321', player_total_kills=6, player_total_deaths=12),
#  Row(match_id='a7edd7e4-ecba-41fb-b507-0d9e37143917', player_gamertag='ZeMo iS SN', player_total_kills=13, player_total_deaths=8),
#  Row(match_id='a7edd7e4-ecba-41fb-b507-0d9e37143917', player_gamertag='iProBang', player_total_kills=12, player_total_deaths=14),
#  Row(match_id='a7edd7e4-ecba-41fb-b507-0d9e37143917', player_gamertag='EcZachly', player_total_kills=12, player_total_deaths=11),
#  Row(match_id='a7edd7e4-ecba-41fb-b507-0d9e37143917', player_gamertag='RORYsREV0LUTI0N', player_total_kills=14, player_total_deaths=13),
#  Row(match_id='a7edd7e4-ecba-41fb-b507-0d9e37143917', player_gamertag='Lil Black BUBBA', player_total_kills=14, player_total_deaths=14),
#  Row(match_id='a7edd7e4-ecba-41fb-b507-0d9e37143917', player_gamertag='Epson ZC36', player_total_kills=15, player_total_deaths=13),
#  Row(match_id='9b5fd26c-bfd4-4a8c-ac26-3a91dc191cb6', player_gamertag='yor poppi', player_total_kills=10, player_total_deaths=13),
#  Row(match_id='9b5fd26c-bfd4-4a8c-ac26-3a91dc191cb6', player_gamertag='ILLICIT 117', player_total_kills=11, player_total_deaths=17),
#  Row(match_id='9b5fd26c-bfd4-4a8c-ac26-3a91dc191cb6', player_gamertag='EcZachly', player_total_kills=9, player_total_deaths=11),
#  Row(match_id='9b5fd26c-bfd4-4a8c-ac26-3a91dc191cb6', player_gamertag='fosterforce', player_total_kills=14, player_total_deaths=13),
#  Row(match_id='9b5fd26c-bfd4-4a8c-ac26-3a91dc191cb6', player_gamertag='BLU3 D3V1L 21', player_total_kills=10, player_total_deaths=10),
#  Row(match_id='9b5fd26c-bfd4-4a8c-ac26-3a91dc191cb6', player_gamertag='Thain117', player_total_kills=13, player_total_deaths=14),
#  Row(match_id='9b5fd26c-bfd4-4a8c-ac26-3a91dc191cb6', player_gamertag='X Fashionista X', player_total_kills=18, player_total_deaths=12),
#  Row(match_id='9b5fd26c-bfd4-4a8c-ac26-3a91dc191cb6', player_gamertag='LlK3 WATER', player_total_kills=12, player_total_deaths=7),
#  Row(match_id='09d410fb-1c50-4119-98f5-3f82f50db390', player_gamertag='Crazyy Dun 3', player_total_kills=9, player_total_deaths=8),
#  Row(match_id='09d410fb-1c50-4119-98f5-3f82f50db390', player_gamertag='RIKY291297', player_total_kills=12, player_total_deaths=12),
#  Row(match_id='09d410fb-1c50-4119-98f5-3f82f50db390', player_gamertag='Gabo Lira', player_total_kills=2, player_total_deaths=8),
#  Row(match_id='09d410fb-1c50-4119-98f5-3f82f50db390', player_gamertag='CristianoGabo7', player_total_kills=6, player_total_deaths=12),
#  Row(match_id='09d410fb-1c50-4119-98f5-3f82f50db390', player_gamertag='Lyzs', player_total_kills=2, player_total_deaths=14),
#  Row(match_id='09d410fb-1c50-4119-98f5-3f82f50db390', player_gamertag='Cynical Spaded', player_total_kills=8, player_total_deaths=9),
#  Row(match_id='09d410fb-1c50-4119-98f5-3f82f50db390', player_gamertag='garay127xD', player_total_kills=10, player_total_deaths=12),
#  Row(match_id='09d410fb-1c50-4119-98f5-3f82f50db390', player_gamertag='Fjaxyu', player_total_kills=8, player_total_deaths=9),
#  Row(match_id='09d410fb-1c50-4119-98f5-3f82f50db390', player_gamertag='EcZachly', player_total_kills=12, player_total_deaths=9),
#  Row(match_id='09d410fb-1c50-4119-98f5-3f82f50db390', player_gamertag='A Fallen Chair', player_total_kills=22, player_total_deaths=7),
#  Row(match_id='09d410fb-1c50-4119-98f5-3f82f50db390', player_gamertag='IcecreamPenguin', player_total_kills=21, player_total_deaths=4),
#  Row(match_id='09d410fb-1c50-4119-98f5-3f82f50db390', player_gamertag='YOGA28xX', player_total_kills=0, player_total_deaths=9),
#  Row(match_id='de462a51-7525-4a38-84b1-a0fc9e65797a', player_gamertag='sSlipperyy', player_total_kills=9, player_total_deaths=11),
#  Row(match_id='de462a51-7525-4a38-84b1-a0fc9e65797a', player_gamertag='D00IVl', player_total_kills=17, player_total_deaths=7),
#  Row(match_id='de462a51-7525-4a38-84b1-a0fc9e65797a', player_gamertag='Ash All Mighty', player_total_kills=12, player_total_deaths=12),
#  Row(match_id='de462a51-7525-4a38-84b1-a0fc9e65797a', player_gamertag='Swarlsz', player_total_kills=10, player_total_deaths=15),
#  Row(match_id='de462a51-7525-4a38-84b1-a0fc9e65797a', player_gamertag='EcZachly', player_total_kills=13, player_total_deaths=15),
#  Row(match_id='de462a51-7525-4a38-84b1-a0fc9e65797a', player_gamertag='LIQUID P0PTART', player_total_kills=19, player_total_deaths=12),
#  Row(match_id='de462a51-7525-4a38-84b1-a0fc9e65797a', player_gamertag='JakeWilson801', player_total_kills=11, player_total_deaths=13),
#  Row(match_id='de462a51-7525-4a38-84b1-a0fc9e65797a', player_gamertag='DreeeMy', player_total_kills=11, player_total_deaths=15),
#  Row(match_id='f61c2bf4-b8c0-484b-bd56-aaf48a5a47e1', player_gamertag='zachster924', player_total_kills=21, player_total_deaths=19),
#  Row(match_id='4c38428a-ab25-467c-a260-172b3412ebc3', player_gamertag='quesodilla', player_total_kills=4, player_total_deaths=5),
#  Row(match_id='4c38428a-ab25-467c-a260-172b3412ebc3', player_gamertag='ChazzMcMichaels', player_total_kills=15, player_total_deaths=4),
#  Row(match_id='4c38428a-ab25-467c-a260-172b3412ebc3', player_gamertag='jaimef11', player_total_kills=4, player_total_deaths=12),
#  Row(match_id='4c38428a-ab25-467c-a260-172b3412ebc3', player_gamertag='ILLICIT 117', player_total_kills=9, player_total_deaths=10),
#  Row(match_id='4c38428a-ab25-467c-a260-172b3412ebc3', player_gamertag='HellknighT pN', player_total_kills=8, player_total_deaths=11),
#  Row(match_id='4c38428a-ab25-467c-a260-172b3412ebc3', player_gamertag='EcZachly', player_total_kills=14, player_total_deaths=2),
#  Row(match_id='4c38428a-ab25-467c-a260-172b3412ebc3', player_gamertag='JayMoney1015', player_total_kills=3, player_total_deaths=12),
#  Row(match_id='4c38428a-ab25-467c-a260-172b3412ebc3', player_gamertag='Br0methiuss', player_total_kills=7, player_total_deaths=8),
#  Row(match_id='bafaea2e-9276-45a3-80d6-38bd9974bdb7', player_gamertag='EcZachly', player_total_kills=5, player_total_deaths=5),
#  Row(match_id='bafaea2e-9276-45a3-80d6-38bd9974bdb7', player_gamertag='Stormbane321', player_total_kills=6, player_total_deaths=3),
#  Row(match_id='bafaea2e-9276-45a3-80d6-38bd9974bdb7', player_gamertag='Tarnished Lord', player_total_kills=3, player_total_deaths=6),
#  Row(match_id='bafaea2e-9276-45a3-80d6-38bd9974bdb7', player_gamertag='SEVER2404', player_total_kills=7, player_total_deaths=4),
#  Row(match_id='bafaea2e-9276-45a3-80d6-38bd9974bdb7', player_gamertag='Ash All Mighty', player_total_kills=5, player_total_deaths=4),
#  Row(match_id='bafaea2e-9276-45a3-80d6-38bd9974bdb7', player_gamertag='Unleash Havoc', player_total_kills=5, player_total_deaths=7),
#  Row(match_id='bafaea2e-9276-45a3-80d6-38bd9974bdb7', player_gamertag='Valetrocity8', player_total_kills=5, player_total_deaths=4),
#  Row(match_id='bafaea2e-9276-45a3-80d6-38bd9974bdb7', player_gamertag='JoeySever10', player_total_kills=1, player_total_deaths=6),
#  Row(match_id='b2e9819c-3fdd-49e8-a6cb-c67530713036', player_gamertag='LancRz', player_total_kills=2, player_total_deaths=4),
#  Row(match_id='b2e9819c-3fdd-49e8-a6cb-c67530713036', player_gamertag='JakeWilson801', player_total_kills=4, player_total_deaths=3),
#  Row(match_id='b2e9819c-3fdd-49e8-a6cb-c67530713036', player_gamertag='JakemRedd', player_total_kills=3, player_total_deaths=4),
#  Row(match_id='b2e9819c-3fdd-49e8-a6cb-c67530713036', player_gamertag='Subject TOAD', player_total_kills=6, player_total_deaths=0),
#  Row(match_id='b2e9819c-3fdd-49e8-a6cb-c67530713036', player_gamertag='EcZachly', player_total_kills=6, player_total_deaths=3),
#  Row(match_id='b2e9819c-3fdd-49e8-a6cb-c67530713036', player_gamertag='Plagueisx', player_total_kills=2, player_total_deaths=5),
#  Row(match_id='b2e9819c-3fdd-49e8-a6cb-c67530713036', player_gamertag='Ash All Mighty', player_total_kills=2, player_total_deaths=3),
#  Row(match_id='b2e9819c-3fdd-49e8-a6cb-c67530713036', player_gamertag='Drew55BSHU', player_total_kills=2, player_total_deaths=5),
#  Row(match_id='1404e51e-abe8-4b76-ab97-605bada0ffde', player_gamertag='I am Bobby Long', player_total_kills=2, player_total_deaths=5),
#  Row(match_id='1404e51e-abe8-4b76-ab97-605bada0ffde', player_gamertag='Stormbane321', player_total_kills=7, player_total_deaths=5),
#  Row(match_id='1404e51e-abe8-4b76-ab97-605bada0ffde', player_gamertag='xSinisterWays', player_total_kills=11, player_total_deaths=3),
#  Row(match_id='1404e51e-abe8-4b76-ab97-605bada0ffde', player_gamertag='ALEX MASTER 98', player_total_kills=4, player_total_deaths=6),
#  Row(match_id='1404e51e-abe8-4b76-ab97-605bada0ffde', player_gamertag='LamentedDuke85', player_total_kills=4, player_total_deaths=6),
#  Row(match_id='1404e51e-abe8-4b76-ab97-605bada0ffde', player_gamertag='EcZachly', player_total_kills=4, player_total_deaths=7),
#  Row(match_id='1404e51e-abe8-4b76-ab97-605bada0ffde', player_gamertag='Ix RING xI', player_total_kills=8, player_total_deaths=4),
#  Row(match_id='1404e51e-abe8-4b76-ab97-605bada0ffde', player_gamertag='wero enigma', player_total_kills=3, player_total_deaths=7),
#  Row(match_id='51c87a8e-6bee-4530-a4a9-8c780d493345', player_gamertag='JakeWilson801', player_total_kills=11, player_total_deaths=15),
# ...
#  Row(match_id='e4c65894-4de5-4bbe-9729-3002de9f08a6', player_gamertag='XRaY NINJA32', player_total_kills=4, player_total_deaths=0),
#  Row(match_id='e4c65894-4de5-4bbe-9729-3002de9f08a6', player_gamertag='ILLICIT 117', player_total_kills=3, player_total_deaths=1),
#  Row(match_id='e4c65894-4de5-4bbe-9729-3002de9f08a6', player_gamertag='Envy Bravo', player_total_kills=0, player_total_deaths=5),
#  Row(match_id='e4c65894-4de5-4bbe-9729-3002de9f08a6', player_gamertag='EcZachly', player_total_kills=4, player_total_deaths=3),
#  Row(match_id='e4c65894-4de5-4bbe-9729-3002de9f08a6', player_gamertag='Jelly xT', player_total_kills=3, player_total_deaths=5),
#  Row(match_id='e4c65894-4de5-4bbe-9729-3002de9f08a6', player_gamertag='Toxic xT', player_total_kills=1, player_total_deaths=5),
#  Row(match_id='e4c65894-4de5-4bbe-9729-3002de9f08a6', player_gamertag='Agly Ayala', player_total_kills=0, player_total_deaths=4),
#  Row(match_id='e4c65894-4de5-4bbe-9729-3002de9f08a6', player_gamertag='GHK Rapp5', player_total_kills=8, player_total_deaths=0),
#  Row(match_id='94f14219-f114-43fa-b6d5-08f46f78f867', player_gamertag='JakeWilson801', player_total_kills=2, player_total_deaths=3),
#  Row(match_id='94f14219-f114-43fa-b6d5-08f46f78f867', player_gamertag='Breezy SVO', player_total_kills=0, player_total_deaths=1),
#  Row(match_id='94f14219-f114-43fa-b6d5-08f46f78f867', player_gamertag='GRAND HUSLTA', player_total_kills=5, player_total_deaths=5),
#  Row(match_id='94f14219-f114-43fa-b6d5-08f46f78f867', player_gamertag='z MDFK ReApEr z', player_total_kills=2, player_total_deaths=4),
#  Row(match_id='94f14219-f114-43fa-b6d5-08f46f78f867', player_gamertag='Swat Lurks', player_total_kills=8, player_total_deaths=5),
#  Row(match_id='94f14219-f114-43fa-b6d5-08f46f78f867', player_gamertag='xXGoonsterXx', player_total_kills=3, player_total_deaths=6),
#  Row(match_id='94f14219-f114-43fa-b6d5-08f46f78f867', player_gamertag='ExTraVaGaNT BuD', player_total_kills=3, player_total_deaths=7),
#  Row(match_id='94f14219-f114-43fa-b6d5-08f46f78f867', player_gamertag='EcZachly', player_total_kills=10, player_total_deaths=2),
#  Row(match_id='15606a0d-3998-4ecb-b1b8-8100c1735810', player_gamertag='JakeWilson801', player_total_kills=2, player_total_deaths=5),
#  Row(match_id='15606a0d-3998-4ecb-b1b8-8100c1735810', player_gamertag='EcZachly', player_total_kills=9, player_total_deaths=7),
#  Row(match_id='15606a0d-3998-4ecb-b1b8-8100c1735810', player_gamertag='NEIGHBOR6907', player_total_kills=2, player_total_deaths=7),
#  Row(match_id='15606a0d-3998-4ecb-b1b8-8100c1735810', player_gamertag='Willey2Gr8', player_total_kills=12, player_total_deaths=7),
#  Row(match_id='15606a0d-3998-4ecb-b1b8-8100c1735810', player_gamertag='Stormbane321', player_total_kills=6, player_total_deaths=7),
#  Row(match_id='15606a0d-3998-4ecb-b1b8-8100c1735810', player_gamertag='FIREKING2250', player_total_kills=1, player_total_deaths=7),
#  Row(match_id='15606a0d-3998-4ecb-b1b8-8100c1735810', player_gamertag='SufferedKR38z', player_total_kills=9, player_total_deaths=6),
#  Row(match_id='15606a0d-3998-4ecb-b1b8-8100c1735810', player_gamertag='The Total FP', player_total_kills=10, player_total_deaths=5),
#  Row(match_id='f8a3d0aa-df07-4890-9dbf-923acde13d85', player_gamertag='ILLICIT 117', player_total_kills=2, player_total_deaths=4),
#  Row(match_id='f8a3d0aa-df07-4890-9dbf-923acde13d85', player_gamertag='EcZachly', player_total_kills=10, player_total_deaths=4),
#  Row(match_id='f8a3d0aa-df07-4890-9dbf-923acde13d85', player_gamertag='Dope Boy', player_total_kills=2, player_total_deaths=7),
#  Row(match_id='f8a3d0aa-df07-4890-9dbf-923acde13d85', player_gamertag='GMain80', player_total_kills=7, player_total_deaths=6),
#  Row(match_id='f8a3d0aa-df07-4890-9dbf-923acde13d85', player_gamertag='Guardian2416', player_total_kills=3, player_total_deaths=5),
#  Row(match_id='f8a3d0aa-df07-4890-9dbf-923acde13d85', player_gamertag='xCAGEDDARKNESSx', player_total_kills=8, player_total_deaths=5),
#  Row(match_id='f8a3d0aa-df07-4890-9dbf-923acde13d85', player_gamertag='GraveStone37', player_total_kills=5, player_total_deaths=5),
#  Row(match_id='f8a3d0aa-df07-4890-9dbf-923acde13d85', player_gamertag='Ultronyte', player_total_kills=3, player_total_deaths=7),
#  Row(match_id='5a0a857c-1aed-4b56-b649-670157ddfc04', player_gamertag='EcZachly', player_total_kills=27, player_total_deaths=20),
#  Row(match_id='5a0a857c-1aed-4b56-b649-670157ddfc04', player_gamertag='Forever Zonic', player_total_kills=16, player_total_deaths=29),
#  Row(match_id='5a0a857c-1aed-4b56-b649-670157ddfc04', player_gamertag='A Trippy Mane', player_total_kills=11, player_total_deaths=26),
#  Row(match_id='5a0a857c-1aed-4b56-b649-670157ddfc04', player_gamertag='Stormbane321', player_total_kills=30, player_total_deaths=18),
#  Row(match_id='5a0a857c-1aed-4b56-b649-670157ddfc04', player_gamertag='Diplex W0lf', player_total_kills=14, player_total_deaths=18),
#  Row(match_id='5a0a857c-1aed-4b56-b649-670157ddfc04', player_gamertag='x StealthSepa x', player_total_kills=34, player_total_deaths=15),
#  Row(match_id='5a0a857c-1aed-4b56-b649-670157ddfc04', player_gamertag='Fjaxyu', player_total_kills=9, player_total_deaths=22),
#  Row(match_id='5a0a857c-1aed-4b56-b649-670157ddfc04', player_gamertag='Wapanator', player_total_kills=22, player_total_deaths=15),
#  Row(match_id='f4121147-e406-4a89-b317-c97f018871c3', player_gamertag='CameInTheBack03', player_total_kills=19, player_total_deaths=4),
#  Row(match_id='f4121147-e406-4a89-b317-c97f018871c3', player_gamertag='ARCHKNIGHT96', player_total_kills=8, player_total_deaths=8),
#  Row(match_id='f4121147-e406-4a89-b317-c97f018871c3', player_gamertag='ImMLGAtThisGame', player_total_kills=5, player_total_deaths=9),
#  Row(match_id='f4121147-e406-4a89-b317-c97f018871c3', player_gamertag='Mocyombi', player_total_kills=11, player_total_deaths=6),
#  Row(match_id='f4121147-e406-4a89-b317-c97f018871c3', player_gamertag='TheFatal FrOsty', player_total_kills=3, player_total_deaths=9),
#  Row(match_id='f4121147-e406-4a89-b317-c97f018871c3', player_gamertag='SultanHengzt45', player_total_kills=3, player_total_deaths=8),
#  Row(match_id='f4121147-e406-4a89-b317-c97f018871c3', player_gamertag='TravelinNomad', player_total_kills=5, player_total_deaths=8),
#  Row(match_id='f4121147-e406-4a89-b317-c97f018871c3', player_gamertag='EcZachly', player_total_kills=6, player_total_deaths=8),
#  Row(match_id='15af5b19-98aa-4362-a7d1-7cb652dc086e', player_gamertag='EcZachly', player_total_kills=2, player_total_deaths=5),
#  Row(match_id='15af5b19-98aa-4362-a7d1-7cb652dc086e', player_gamertag='Black Tiger66', player_total_kills=5, player_total_deaths=5),
#  Row(match_id='15af5b19-98aa-4362-a7d1-7cb652dc086e', player_gamertag='DiNo DaAn', player_total_kills=4, player_total_deaths=4),
#  Row(match_id='15af5b19-98aa-4362-a7d1-7cb652dc086e', player_gamertag='p4n13c', player_total_kills=3, player_total_deaths=5),
#  Row(match_id='15af5b19-98aa-4362-a7d1-7cb652dc086e', player_gamertag='Tans1234', player_total_kills=5, player_total_deaths=6),
#  Row(match_id='15af5b19-98aa-4362-a7d1-7cb652dc086e', player_gamertag='Urkel Billz', player_total_kills=7, player_total_deaths=2),
#  Row(match_id='15af5b19-98aa-4362-a7d1-7cb652dc086e', player_gamertag='TOMeightoh', player_total_kills=7, player_total_deaths=4),
#  Row(match_id='15af5b19-98aa-4362-a7d1-7cb652dc086e', player_gamertag='RogerProfk98', player_total_kills=2, player_total_deaths=5),
#  Row(match_id='ce3acec9-0854-4348-98c2-f6461e4ee669', player_gamertag='Haff3yy', player_total_kills=1, player_total_deaths=7),
#  Row(match_id='ce3acec9-0854-4348-98c2-f6461e4ee669', player_gamertag='Shwuh', player_total_kills=14, player_total_deaths=20),
#  Row(match_id='ce3acec9-0854-4348-98c2-f6461e4ee669', player_gamertag='EcZachly', player_total_kills=19, player_total_deaths=15),
#  Row(match_id='ce3acec9-0854-4348-98c2-f6461e4ee669', player_gamertag='JAYT1N', player_total_kills=13, player_total_deaths=19),
#  Row(match_id='ce3acec9-0854-4348-98c2-f6461e4ee669', player_gamertag='Valium I', player_total_kills=25, player_total_deaths=12),
#  Row(match_id='ce3acec9-0854-4348-98c2-f6461e4ee669', player_gamertag='Snipes Jesus', player_total_kills=17, player_total_deaths=15),
#  Row(match_id='ce3acec9-0854-4348-98c2-f6461e4ee669', player_gamertag='xXMAINPUREXx', player_total_kills=19, player_total_deaths=21),
#  Row(match_id='ce3acec9-0854-4348-98c2-f6461e4ee669', player_gamertag='Mista Piddles', player_total_kills=17, player_total_deaths=16),
#  Row(match_id='3313f8c8-3011-40ac-b757-56452ac48fb4', player_gamertag='Irishnoble', player_total_kills=15, player_total_deaths=20),
#  Row(match_id='3313f8c8-3011-40ac-b757-56452ac48fb4', player_gamertag='EcZachly', player_total_kills=20, player_total_deaths=20),
#  Row(match_id='3313f8c8-3011-40ac-b757-56452ac48fb4', player_gamertag='Heavens7thCloud', player_total_kills=14, player_total_deaths=16),
#  Row(match_id='3313f8c8-3011-40ac-b757-56452ac48fb4', player_gamertag='That Paladin', player_total_kills=18, player_total_deaths=18),
#  Row(match_id='3313f8c8-3011-40ac-b757-56452ac48fb4', player_gamertag='ShreddedTITAN23', player_total_kills=13, player_total_deaths=16),
#  Row(match_id='3313f8c8-3011-40ac-b757-56452ac48fb4', player_gamertag='TheMADHATTER5', player_total_kills=15, player_total_deaths=14),
#  Row(match_id='3313f8c8-3011-40ac-b757-56452ac48fb4', player_gamertag='Scondras', player_total_kills=25, player_total_deaths=16),
#  Row(match_id='3313f8c8-3011-40ac-b757-56452ac48fb4', player_gamertag='k wriight', player_total_kills=17, player_total_deaths=17),
#  Row(match_id='a61c0c9b-95d9-4e72-9a1f-424bea8f40e8', player_gamertag='JakeWilson801', player_total_kills=7, player_total_deaths=6),
#  Row(match_id='a61c0c9b-95d9-4e72-9a1f-424bea8f40e8', player_gamertag='TactileBiscuit4', player_total_kills=5, player_total_deaths=6),
#  Row(match_id='a61c0c9b-95d9-4e72-9a1f-424bea8f40e8', player_gamertag='Ash All Mighty', player_total_kills=4, player_total_deaths=8),
#  Row(match_id='a61c0c9b-95d9-4e72-9a1f-424bea8f40e8', player_gamertag='EternalHero11', player_total_kills=9, player_total_deaths=4),
#  Row(match_id='a61c0c9b-95d9-4e72-9a1f-424bea8f40e8', player_gamertag='EternalRaven11', player_total_kills=5, player_total_deaths=4),
#  Row(match_id='a61c0c9b-95d9-4e72-9a1f-424bea8f40e8', player_gamertag='SilentxLegend', player_total_kills=9, player_total_deaths=5),
#  Row(match_id='a61c0c9b-95d9-4e72-9a1f-424bea8f40e8', player_gamertag='EcZachly', player_total_kills=3, player_total_deaths=5),
#  Row(match_id='a61c0c9b-95d9-4e72-9a1f-424bea8f40e8', player_gamertag='The Blaxicino', player_total_kills=2, player_total_deaths=6),
#  Row(match_id='8a8d800c-565f-4557-8e83-596cba0b868e', player_gamertag='ArguingAbyss', player_total_kills=10, player_total_deaths=9),
#  Row(match_id='8a8d800c-565f-4557-8e83-596cba0b868e', player_gamertag='I RTR Apollo I', player_total_kills=13, player_total_deaths=8),
#  Row(match_id='8a8d800c-565f-4557-8e83-596cba0b868e', player_gamertag='eA CarPix', player_total_kills=8, player_total_deaths=8),
#  Row(match_id='8a8d800c-565f-4557-8e83-596cba0b868e', player_gamertag='SumbaeXkami', player_total_kills=10, player_total_deaths=5),
#  Row(match_id='8a8d800c-565f-4557-8e83-596cba0b868e', player_gamertag='EcZachly', player_total_kills=5, player_total_deaths=9),
#  Row(match_id='8a8d800c-565f-4557-8e83-596cba0b868e', player_gamertag='THE LAW RTR', player_total_kills=3, player_total_deaths=5),
#  Row(match_id='8a8d800c-565f-4557-8e83-596cba0b868e', player_gamertag='ZURUEL AGM', player_total_kills=7, player_total_deaths=7),
#  Row(match_id='8a8d800c-565f-4557-8e83-596cba0b868e', player_gamertag='GILGAMESH AGM', player_total_kills=6, player_total_deaths=11),
#  Row(match_id='4d46690a-6daa-46e7-aa60-9c02d3b766ec', player_gamertag='Portugues BA', player_total_kills=2, player_total_deaths=3),
#  Row(match_id='4d46690a-6daa-46e7-aa60-9c02d3b766ec', player_gamertag='ILLICIT 117', player_total_kills=4, player_total_deaths=5),
#  Row(match_id='4d46690a-6daa-46e7-aa60-9c02d3b766ec', player_gamertag='EcZachly', player_total_kills=4, player_total_deaths=2),
#  Row(match_id='4d46690a-6daa-46e7-aa60-9c02d3b766ec', player_gamertag='Attack Rabbits', player_total_kills=6, player_total_deaths=3),
#  Row(match_id='4d46690a-6daa-46e7-aa60-9c02d3b766ec', player_gamertag='Icin9death', player_total_kills=1, player_total_deaths=4),
#  Row(match_id='4d46690a-6daa-46e7-aa60-9c02d3b766ec', player_gamertag='TheGrizzMan69', player_total_kills=3, player_total_deaths=4),
#  Row(match_id='4d46690a-6daa-46e7-aa60-9c02d3b766ec', player_gamertag='BernardoWasHere', player_total_kills=5, player_total_deaths=4),
#  Row(match_id='528ccdad-51b6-4d35-b1aa-d2880a7f867e', player_gamertag='PlupMaster', player_total_kills=11, player_total_deaths=28),
#  Row(match_id='528ccdad-51b6-4d35-b1aa-d2880a7f867e', player_gamertag='TonytHeponY66', player_total_kills=34, player_total_deaths=33),
#  Row(match_id='528ccdad-51b6-4d35-b1aa-d2880a7f867e', player_gamertag='theH1GHlife', player_total_kills=48, player_total_deaths=34),
#  Row(match_id='4d46690a-6daa-46e7-aa60-9c02d3b766ec', player_gamertag='butterblack ops', player_total_kills=3, player_total_deaths=3),
#  Row(match_id='528ccdad-51b6-4d35-b1aa-d2880a7f867e', player_gamertag='Yaid69', player_total_kills=34, player_total_deaths=39),
#  Row(match_id='528ccdad-51b6-4d35-b1aa-d2880a7f867e', player_gamertag='DPD Jacob', player_total_kills=35, player_total_deaths=28),
#  Row(match_id='528ccdad-51b6-4d35-b1aa-d2880a7f867e', player_gamertag='YukioGamers', player_total_kills=0, player_total_deaths=11),
#  Row(match_id='528ccdad-51b6-4d35-b1aa-d2880a7f867e', player_gamertag='Bigmoney1991919', player_total_kills=28, player_total_deaths=22),
#  Row(match_id='7bd2cd33-35b0-4668-8d14-8f2fb714e2dc', player_gamertag='HaTe Hydro', player_total_kills=8, player_total_deaths=11),
#  Row(match_id='7bd2cd33-35b0-4668-8d14-8f2fb714e2dc', player_gamertag='EcZachly', player_total_kills=13, player_total_deaths=14),
#  Row(match_id='7bd2cd33-35b0-4668-8d14-8f2fb714e2dc', player_gamertag='YouTube Trauma', player_total_kills=11, player_total_deaths=11),
#  Row(match_id='7bd2cd33-35b0-4668-8d14-8f2fb714e2dc', player_gamertag='GallantHickory9', player_total_kills=11, player_total_deaths=15),
#  Row(match_id='7bd2cd33-35b0-4668-8d14-8f2fb714e2dc', player_gamertag='Jest3r 2 1 7', player_total_kills=14, player_total_deaths=12),
#  Row(match_id='7bd2cd33-35b0-4668-8d14-8f2fb714e2dc', player_gamertag='ItZ S0 AmaZ1N', player_total_kills=19, player_total_deaths=13),
#  Row(match_id='7bd2cd33-35b0-4668-8d14-8f2fb714e2dc', player_gamertag='Stormbane321', player_total_kills=9, player_total_deaths=14),
#  Row(match_id='7bd2cd33-35b0-4668-8d14-8f2fb714e2dc', player_gamertag='MVP Kleanup', player_total_kills=14, player_total_deaths=9),
#  Row(match_id='528ccdad-51b6-4d35-b1aa-d2880a7f867e', player_gamertag='PIX3L77', player_total_kills=25, player_total_deaths=31),
#  Row(match_id='892070dc-0044-469b-843c-2f294d693653', player_gamertag='StarLord0407', player_total_kills=5, player_total_deaths=7),
#  Row(match_id='892070dc-0044-469b-843c-2f294d693653', player_gamertag='ImpishNood1e', player_total_kills=3, player_total_deaths=7),
#  Row(match_id='892070dc-0044-469b-843c-2f294d693653', player_gamertag='mojo jojo 00012', player_total_kills=5, player_total_deaths=5),
#  Row(match_id='892070dc-0044-469b-843c-2f294d693653', player_gamertag='Chadington1017', player_total_kills=4, player_total_deaths=6),
#  Row(match_id='892070dc-0044-469b-843c-2f294d693653', player_gamertag='butterblack ops', player_total_kills=3, player_total_deaths=8),
#  Row(match_id='892070dc-0044-469b-843c-2f294d693653', player_gamertag='gemanovich', player_total_kills=8, player_total_deaths=5),
#  Row(match_id='528ccdad-51b6-4d35-b1aa-d2880a7f867e', player_gamertag='Stormbane321', player_total_kills=25, player_total_deaths=18),
#  Row(match_id='892070dc-0044-469b-843c-2f294d693653', player_gamertag='EcZachly', player_total_kills=12, player_total_deaths=4),
#  Row(match_id='892070dc-0044-469b-843c-2f294d693653', player_gamertag='THE WRAITH KMK', player_total_kills=10, player_total_deaths=8),
#  ...]

# %%
# Medals Matches Players

spark.sql("""DROP TABLE IF EXISTS bootcamp.medals_matches_players_bucketed""")

medals_matches_players_bucketedDDL = """
CREATE TABLE IF NOT EXISTS bootcamp.medals_matches_players_bucketed (
    match_id STRING,
    player_gamertag STRING,
    medal_id STRING,
    classification STRING,
    description STRING,
    difficulty STRING,
    count INTEGER
)
 USING iceberg
 PARTITIONED BY (bucket(16, match_id));
"""

spark.sql(medals_matches_players_bucketedDDL)

medals_matches_players_df.select(col("match_id"),col("player_gamertag"),col("medal_id"), col("classification"), col("description"), col("difficulty"), col("count")) \
                      .write.mode("append") \
                      .bucketBy(16, "match_id").saveAsTable("bootcamp.medals_matches_players_bucketed")

# %%
# Join medals_matches_players, match_details, matches on bucketed 16

md_df = spark.table("bootcamp.match_details_bucketed")
m_df = spark.table("bootcamp.matches_bucketed")
mmp_df = spark.table("bootcamp.medals_matches_players_bucketed")

result_df = (
    md_df.alias("mdb")
    .join(
        m_df.alias("md"),
        on=md_df.match_id == m_df.match_id,
    )
    .join(
        mmp_df.alias("mmp"),
        on=(
            (md_df.match_id == mmp_df.match_id)
            & (md_df.player_gamertag == mmp_df.player_gamertag)
        ),
    )
    # Select the required columns
    .select(
        "mdb.match_id",
        "mdb.player_gamertag",
        "mdb.player_total_kills",
        "mdb.player_total_deaths",
        "md.playlist_id",
        "md.map_id",
        "md.name",
        "md.completion_date",
        "mmp.medal_id",
        "mmp.classification",
        "mmp.count",
    )
)

result_df.show()


# spark.sql("""
#     SELECT 
#     mdb.match_id, mdb.player_gamertag, mdb.player_total_kills, mdb.player_total_deaths, md.playlist_id, md.completion_date, mmp.medal_id, mmp.count AS medal_count
#     FROM bootcamp.match_details_bucketed mdb
#     JOIN bootcamp.matches_bucketed md
#     ON mdb.match_id = md.match_id
#     JOIN bootcamp.medals_matches_players_bucketed mmp
#     ON mdb.match_id = mmp.match_id AND mdb.player_gamertag = mmp.player_gamertag
# """)
# Out:
# +--------------------+---------------+------------------+-------------------+--------------------+--------------------+-------+---------------+----------+-----------------+-----+
# |            match_id|player_gamertag|player_total_kills|player_total_deaths|         playlist_id|              map_id|   name|completion_date|  medal_id|   classification|count|
# +--------------------+---------------+------------------+-------------------+--------------------+--------------------+-------+---------------+----------+-----------------+-----+
# |0001a1c4-83dc-4f4...|    ILLICIT 117|                23|                 28|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06|3565443938|      Strongholds|    4|
# |0001a1c4-83dc-4f4...|    ILLICIT 117|                23|                 28|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06|3261908037|WeaponProficiency|    8|
# |0001a1c4-83dc-4f4...|    ILLICIT 117|                23|                 28|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06| 824733727|            Style|    1|
# |0001a1c4-83dc-4f4...|    ILLICIT 117|                23|                 28|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06| 298813630|            Style|    2|
# |0001a1c4-83dc-4f4...|    ILLICIT 117|                23|                 28|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06|1351381581|      Strongholds|    3|
# |0001a1c4-83dc-4f4...|    ILLICIT 117|                23|                 28|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06|2916014239|            Style|    5|
# |0001a1c4-83dc-4f4...|    ILLICIT 117|                23|                 28|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06|1326375333|            Style|    1|
# |0001a1c4-83dc-4f4...|    ILLICIT 117|                23|                 28|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06|3744028405|            Style|    1|
# |0001a1c4-83dc-4f4...|    ILLICIT 117|                23|                 28|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06|3400287617|            Style|    1|
# |0001a1c4-83dc-4f4...|    ILLICIT 117|                23|                 28|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06|3676723563|         Vehicles|    1|
# |0001a1c4-83dc-4f4...|    ILLICIT 117|                23|                 28|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06|2105198095|      Strongholds|    2|
# |0001a1c4-83dc-4f4...|    ILLICIT 117|                23|                 28|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06| 250435527|            Style|    1|
# |0001a1c4-83dc-4f4...|    JASHOBEAM11|                21|                 18|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06|1637841390|      Strongholds|    2|
# |0001a1c4-83dc-4f4...|    JASHOBEAM11|                21|                 18|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06|3565443938|      Strongholds|    6|
# |0001a1c4-83dc-4f4...|    JASHOBEAM11|                21|                 18|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06|3261908037|WeaponProficiency|   10|
# |0001a1c4-83dc-4f4...|    JASHOBEAM11|                21|                 18|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06|1326375333|            Style|    2|
# |0001a1c4-83dc-4f4...|    JASHOBEAM11|                21|                 18|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06|3676723563|         Vehicles|    1|
# |0001a1c4-83dc-4f4...|    JASHOBEAM11|                21|                 18|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06|2916014239|            Style|    2|
# |0001a1c4-83dc-4f4...|    JASHOBEAM11|                21|                 18|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06|1351381581|      Strongholds|    4|
# |0001a1c4-83dc-4f4...|    JASHOBEAM11|                21|                 18|780cc101-005c-4fc...|c7805740-f206-11e...|Glacier|     2016-01-06|2287626681|            Style|    1|
# +--------------------+---------------+------------------+-------------------+--------------------+--------------------+-------+---------------+----------+-----------------+-----+
# only showing top 20 rows

# %%
# Create aggregated table for reference

spark.sql("""DROP TABLE IF EXISTS bootcamp.aggregated_table""")

agg_table_DDL = """ 
CREATE TABLE IF NOT EXISTS bootcamp.aggregated_table (
    match_id STRING, 
    player_gamertag STRING,
    player_total_kills INTEGER,
    player_total_deaths INTEGER,
    playlist_id STRING,
    map_id STRING,
    name STRING,
    completion_date DATE,
    medal_id STRING,
    classification STRING,
    count INTEGER
)
"""

spark.sql(agg_table_DDL)

result_df.select("*") \
         .write.mode("append") \
         .saveAsTable("bootcamp.aggregated_table")

# %%
#Which player averages the most kills per game? 
most_kills_per_game = result_df.groupBy(["player_gamertag", "match_id"]) \
                               .agg({"player_total_kills": "avg"}) \
                               .orderBy("avg(player_total_kills)",ascending=False) \
                               .show(n=1)
# Out:
# +---------------+--------------------+-----------------------+
# |player_gamertag|            match_id|avg(player_total_kills)|
# +---------------+--------------------+-----------------------+
# |   gimpinator14|acf0e47e-20ac-4b1...|                  109.0|
# +---------------+--------------------+-----------------------+
# only showing top 1 row

# %%
#Which playlist gets played the most?
most_played_playlist = result_df.groupBy(["playlist_id"]) \
                                .count() \
                                .orderBy("count",ascending=False) \
                                .show(n=1)
# Out:
# +--------------------+------+
# |         playlist_id| count|
# +--------------------+------+
# |f72e0ef0-7c4a-430...|202489|
# +--------------------+------+
# only showing top 1 row

# %%
#Which map gets played the most?
most_played_map = result_df.groupBy(["map_id", "name"]) \
                           .count() \
                           .orderBy("count",ascending=False) \
                           .show(n=1)
# Out:
# +--------------------+--------------+------+
# |              map_id|          name| count|
# +--------------------+--------------+------+
# |c7edbf0f-f206-11e...|Breakout Arena|186118|
# +--------------------+--------------+------+
# only showing top 1 row

# %%
#Which map do players get the most killing spree medals on? 
most_killing_spree = result_df.groupBy(["map_id", "name", "classification"]) \
                              .agg({"count": "sum"}) \
                              .filter(result_df.classification == "KillingSpree") \
                              .orderBy("sum(count)", ascending=False) \
                              .show(n=1)

# Corresponding SQL
# spark.sql(""" 
# SELECT 
# map_id, name, classification, SUM(count) AS total_KS_medals
# FROM 
# bootcamp.aggregated_table
# GROUP BY map_id, name, classification
# HAVING classification = 'KillingSpree'
# ORDER BY total_ks_medals DESC
# """).show()
# Out:
# 24/12/25 07:39:42 WARN DataSourceV2Strategy: Can't translate true to source filter, unsupported expression
# +--------------------+--------------+--------------+----------+
# |              map_id|          name|classification|sum(count)|
# +--------------------+--------------+--------------+----------+
# |c7edbf0f-f206-11e...|Breakout Arena|  KillingSpree|      6919|
# +--------------------+--------------+--------------+----------+
# only showing top 1 row

# %%
#DDL for Unsorted Agg Table
spark.sql("""DROP TABLE IF EXISTS bootcamp.unsorted_agg_table""")

unsorted_agg_table = """ 
CREATE TABLE IF NOT EXISTS bootcamp.unsorted_agg_table (
    match_id STRING, 
    player_gamertag STRING,
    player_total_kills INTEGER,
    player_total_deaths INTEGER,
    playlist_id STRING,
    map_id STRING,
    name STRING,
    completion_date DATE,
    medal_id STRING,
    classification STRING,
    count INTEGER
)
"""

spark.sql(unsorted_agg_table)

result_df.select("*") \
         .write.mode("append") \
         .saveAsTable("bootcamp.unsorted_agg_table")

# %%
#DDL for Sorted Agg Table
spark.sql("""DROP TABLE IF EXISTS bootcamp.sorted_agg_table""")

sorted_agg_table = """ 
CREATE TABLE IF NOT EXISTS bootcamp.sorted_agg_table (
    match_id STRING, 
    player_gamertag STRING,
    player_total_kills INTEGER,
    player_total_deaths INTEGER,
    playlist_id STRING,
    map_id STRING,
    name STRING,
    completion_date DATE,
    medal_id STRING,
    classification STRING,
    count INTEGER
)
"""

spark.sql(sorted_agg_table)

result_df.select("*") \
         .write.mode("append") \
         .saveAsTable("bootcamp.sorted_agg_table")

# %%
#Different Partition
start_df = result_df.repartition(4, col("playlist_id"))
    
first_sort_df = start_df.sortWithinPartitions(col("playlist_id"), col("map_id"))

start_df.write.mode("overwrite").saveAsTable("bootcamp.unsorted_agg_table")
first_sort_df.write.mode("overwrite").saveAsTable("bootcamp.sorted_agg_table")

# %%
spark.sql("""SELECT SUM(file_size_in_bytes) as size, COUNT(1) as num_files, 'sorted' 
FROM demo.bootcamp.sorted_agg_table.files
UNION ALL
SELECT SUM(file_size_in_bytes) as size, COUNT(1) as num_files, 'unsorted' 
FROM demo.bootcamp.unsorted_agg_table.files
""").show()
# Out:
# +-------+---------+--------+
# |   size|num_files|  sorted|
# +-------+---------+--------+
# |4071612|        4|  sorted|
# |4740813|        4|unsorted|
# +-------+---------+--------+
